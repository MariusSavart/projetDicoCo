# %% [markdown]
# # Scrap and Parse

# %% [markdown]
# ## Scraping

# %%
import requests

# %%
urlTarget = "https://www.linguee.fr/francais-anglais/search?source=auto&query=flower"
response = requests.get(urlTarget)
soup = BeautifulSoup(response.text,'html.parser')
souplettesBody = soup.find('div')
word = souplettesBody.findAll('div',{"class":"isForeignTerm"})

files = souplettesBody.findAll('a',{"class":"audio"})
word = [v.find("a").text.strip() for v in word][0]
print(word)
#files = [{}]
#print(word)
#print(mp3File[0])
files_split = files[0]["onclick"].replace("playSound","").replace(";","").replace("\"", "").split(",")
files_split = {files_split[1].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[1]+".mp3",files_split[3].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[3]+".mp3"}

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<html il_FR il_FR\'>\r\n<head>\r\n<meta http-equiv=\'Content-Type\' content=\'text/html; charset=ISO-8859-15\' >\r\n<meta name=\'description\' content=\'De très nombreux exemples de phrases traduites contenant "flower" &ndash; Dictionnaire français-anglais et moteur de recherche de traductions françaises.\' >\r\n<meta name=\'keywords\' content=\'flower, Linguee, anglais, dictionnaire, traductions, français, dictionnaire anglais, moteur de recherche, traduction\'>\r\n<meta name=\'language\' content=\'fr\'>\r\n<meta http-equiv=\'content-language\' content=\'fr\'>\r\n<meta name=\'og:image\' content=\'https://d1wigddrwdtsce.cloudfront.net/img5/ogimage.jpg\'>\r\n<meta property=\'og:image:type\' content=\'image/jpeg\' />\r\n<meta property=\'og:image:width\' content=\'1200\' />\r\n<meta property=\'og:image:height\' content=\'630\' />\r\n<meta property=\'og:site_name\' content=\'Linguee.fr\'>\r\n<meta property=\'title\' content=\'flower - Traduction française &ndash; Linguee\'>\r\n<meta property=\'og:title\' content=\'flower - Traduction française &ndash; Linguee\'>\r\n<meta property=\'og:description\' content=\'De très nombreux exemples de phrases traduites contenant "flower" &ndash; Dictionnaire français-anglais et moteur de recherche de traductions françaises.\'>\r\n<meta name=\'robots\' content=\'index, follow\'>\r\n<link rel=\'canonical\' href=\'https://www.linguee.fr/anglais-francais/traduction/flower.html\'>\r\n<meta property=\'og:url\' content=\'https://www.linguee.fr/anglais-francais/traduction/flower.html\'>\r\n<link rel=\'alternate\' media=\'screen and (os: ios)\' href=\'ios-app://338225335/www.linguee.fr/anglais-francais/traduction/flower.html\'>\r\n<link rel=\'alternate\' media=\'screen and (os: android)\' href=\'android-app://com.linguee.linguee/http/www.linguee.fr/anglais-francais/traduction/flower.html\'>\r\n<meta property=\'al:ios:url\' content=\'linguee://www.linguee.fr/anglais-francais/traduction/flower.html\'>\r\n<meta property=\'al:ios:app_store_id\' content=\'338225335\'>\r\n<meta property=\'al:ios:app_name\' content=\'Linguee\'>\r\n<link rel=\'apple-touch-icon\' sizes=\'180x180\' href=\'https://d1wigddrwdtsce.cloudfront.net/img5/apple-touch-icon.png\'>\r\n<link rel=\'icon\' type=\'image/svg+xml\' sizes=\'any\' href=\'https://d1wigddrwdtsce.cloudfront.net/img5/favicon.svg\'>\r\n<link rel=\'icon\' type=\'image/png\' sizes=\'32x32\' href=\'https://d1wigddrwdtsce.cloudfront.net/img5/favicon-32x32.png\'>\r\n<link rel=\'icon\' type=\'image/png\' sizes=\'16x16\' href=\'https://d1wigddrwdtsce.cloudfront.net/img5/favicon-16x16.png\'>\r\n <script>\r\n document.addEventListener(\'cmpGUIShow\', function(event){\r\nM.requireAsync([\'DAP\'], function (dap) { dap.sendEvent(dap.EVENTID_CONSENT_SHOW, dap.PAGEID_SEARCH, {}); });\r\n       });\r\n document.addEventListener(\'cmpGUISubmit\', function(event){\r\nM.requireAsync([\'DAP\'], function (dap) { __tcfapi(\'getTCData\', 2, (tcData, success) => { dap.refreshUID(tcData); }, null);dap.sendEvent(dap.EVENTID_CONSENT_SUBMIT, dap.PAGEID_SEARCH, {}); });\r\n       });\r\n document.addEventListener(\'cmpConsentAvailable\', function(event){\r\nM.requireAsync([\'DAP\'], function (dap) { __tcfapi(\'getTCData\', 2, (tcData, success) => { dap.refreshUID(tcData); }, null);dap.sendEvent(dap.EVENTID_CONSENT_AVAILABLE, dap.PAGEID_SEARCH, {}); });\r\n       });\r\n </script>\r\n<meta name=\'viewport\' content=\'width=device-width, initial-scale=1, user-scalable=0\' />\r\n<meta name=\'google\' value=\'notranslate\' />\r\n<link rel=\'apple-touch-icon\' href=\'https://d1wigddrwdtsce.cloudfront.net/img5/apple-touch-icon3.png\'/><meta name=\'apple-mobile-web-app-title\' content=\'Linguee\'>\r\n<title>flower - Traduction française &ndash; Linguee</title>\r\n<style>#small_logo,#search_button,#search_button2,a.audio,a.expand_i,.source_url,.warnSign,.warnSign2{background-image:url(https://d1wigddrwdtsce.cloudfront.net/img5/sprites15.png);background-repeat:no-repeat}body,#header,#hea ...

# %%
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Server': 'nginx/1.18.0 (Ubuntu)', 'Date': 'Wed, 12 Jan 2022 13:47:54 GMT', 'Content-Type': 'text/html; charset="iso-8859-15"', 'Content-Length': '32245', 'Connection': 'keep-alive', 'set-cookie': 'cookie=; Expires=Thu, 01-Jan-1970 00:00:01 GMT; Path=/, number_query_frequency=; Expires=Thu, 01-Jan-1970 00:00:01 GMT; Path=/; Domain=.linguee.fr, number_query_frequency=; Expires=Thu, 01-Jan-1970 00:00:01 GMT; Path=/, sum_query_frequency=; Expires=Thu, 01-Jan-1970 00:00:01 GMT; Path=/; Domain=.linguee.fr, sum_query_frequency=; Expires=Thu, 01-Jan-1970 00:00:01 GMT; Path=/, numberQueriesAfterRelaunch=; Expires=Thu, 01-Jan-1970 00:00:01 GMT; Path=/; Domain=.linguee.fr, numberQueriesAfterRelaunch=; Expires=Thu, 01-Jan-1970 00:00:01 GMT; Path=/, ForeignLang=EN; Max-Age=63072000; Path=/, cookie=569a3f88-2bb7-8bf4-de44-a8ecd0de46ff:1; Max-Age=63072000; Path=/; Domain=.linguee.fr', 'via': '1.0 web22.linguee.com:8080', 'cache-control': 'max-age=0', 'expires': 'Wed, 12 Jan 2022 13:47:54 GMT', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip'}

# %%
response.headers['content-type']
# Out:
# 'text/html; charset="iso-8859-15"'

# %% [markdown]
# ## Parsing

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(response.text,'html.parser')
souplettesBody = soup.find('div')
word = souplettesBody.findAll('div',{"class":"isForeignTerm"})

files = souplettesBody.findAll('a',{"class":"audio"})
word = [v.find("a").text.strip() for v in word][0]
print(word)
#files = [{}]
#print(word)
#print(mp3File[0])
files_split = files[0]["onclick"].replace("playSound","").replace(";","").replace("\"", "").split(",")
files_split = {files_split[1].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[1]+".mp3",files_split[3].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[3]+".mp3"}
# Out:
# <!DOCTYPE html>
#
# <html il_fr="" il_fr'="">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content='De très nombreux exemples de phrases traduites contenant "flower" – Dictionnaire français-anglais et moteur de recherche de traductions françaises.' name="description"/>
# <meta content="flower, Linguee, anglais, dictionnaire, traductions, français, dictionnaire anglais, moteur de recherche, traduction" name="keywords"/>
# <meta content="fr" name="language"/>
# <meta content="fr" http-equiv="content-language"/>
# <meta content="https://d1wigddrwdtsce.cloudfront.net/img5/ogimage.jpg" name="og:image"/>
# <meta content="image/jpeg" property="og:image:type">
# <meta content="1200" property="og:image:width">
# <meta content="630" property="og:image:height">
# <meta content="Linguee.fr" property="og:site_name"/>
# <meta content="flower - Traduction française – Linguee" property="title"/>
# <meta content="flower - Traduction française – Linguee" property="og:title"/>
# <meta content='De très nombreux exemples de phrases traduites contenant "flower" – Dictionnaire français-anglais et moteur de recherche de traductions françaises.' property="og:description"/>
# <meta content="index, follow" name="robots"/>
# <link href="https://www.linguee.fr/anglais-francais/traduction/flower.html" rel="canonical"/>
# <meta content="https://www.linguee.fr/anglais-francais/traduction/flower.html" property="og:url"/>
# <link href="ios-app://338225335/www.linguee.fr/anglais-francais/traduction/flower.html" media="screen and (os: ios)" rel="alternate"/>
# <link href="android-app://com.linguee.linguee/http/www.linguee.fr/anglais-francais/traduction/flower.html" media="screen and (os: android)" rel="alternate"/>
# <meta content="linguee://www.linguee.fr/anglais-francais/traduction/flower.html" property="al:ios:url"/>
# <meta content="338225335" property="al:ios:app_store_id"/>
# <meta content="Linguee" property="al:ios:app_name"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/favicon.svg" rel="icon" sizes="any" type="image/svg+xml"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <script>
#  document.addEventListener('cmpGUIShow', function(event){
# M.requireAsync(['DAP'], function (dap) { dap.sendEvent(dap.EVENTID_CONSENT_SHOW, dap.PAGEID_SEARCH, {}); });
#        });
#  document.addEventListener('cmpGUISubmit', function(event){
# M.requireAsync(['DAP'], function (dap) { __tcfapi('getTCData', 2, (tcData, success) => { dap.refreshUID(tcData); }, null);dap.sendEvent(dap.EVENTID_CONSENT_SUBMIT, dap.PAGEID_SEARCH, {}); });
#        });
#  document.addEventListener('cmpConsentAvailable', function(event){
# M.requireAsync(['DAP'], function (dap) { __tcfapi('getTCData', 2, (tcData, success) => { dap.refreshUID(tcData); }, null);dap.sendEvent(dap.EVENTID_CONSENT_AVAILABLE, dap.PAGEID_SEARCH, {}); });
#        });
#  </script>
# <meta content="width=device-width, initial-scale=1, user-scalable=0" name="viewport">
# <meta name="google" value="notranslate">
# <link href="https://d1wigddrwdtsce.cloudfront.net/img5/apple-touch-icon3.png" rel="apple-touch-icon"><meta content="Linguee" name="apple-mobile-web-app-title"/>
# <title>flower - Traduction française – Linguee</title>
# <style>#small_logo,#search_button,#search_button2,a.audio,a.expand_i,.source_url,.warnSign,.warnSign2{background-image:url(https://d1wigddrwdtsce.cloudfront.net/img5/sprites15.png);background-repeat:no-repeat}body,#header,#header input{font-family:Avenir Next,Roboto Condensed,Arial,sans-serif}body{background-color:#dedede;margin:0;padding:0;color:#3c3c3c;-webkit-text-size-adjust:100%}html{background-color:#f1f1f1;height:100%}#outer_div{max-width:1090px;min-width:620px;margin-left:auto;margin-right:auto;position:relative}#ip_page_wrapper,#l_page_wrapper,#ip_content_wrapper,#outer_div{min-height:100%;height:100%}img{display:block;border:0}a{color:inherit}a[href],a[onclick],a[href] b{cursor:pointer}a:link,a:visited{text-decoration:none}.bold{font-weight:bold}td{padding:0;text-align:left}th{padding:7px 0 3px 0;text-align:left;font-weight:bold;font-size:.7em;color:#333}#linguee{float:left}h1.noresults{font-weight:400;font-style:italic;font-size:18px;text-align:center;margin-top:30px}#header{position:relative;padding:0;margin-bottom:15px;height:80px}#footer{display:none}#attribution,#important_terms,#currently_searched{display:none}#social_media_toggles{display:none}#form1{margin:0}#selectionPopup{display:none}#lingueecontent{min-height:300px;margin:2px 0 150px 0;position:relative;color:#333;overflow:visible;background:white}.tooltip{display:none}.innercontent{clear:both}#maindiv{background-color:#fff;padding-bottom:80px;margin:0;position:relative;top:0;min-height:100%}#layoutmain{padding:3px 0 0 0;margin:0;vertical-align:top}.resultpage #maindiv{min-height:1200px}#reportAdForm,#footer-overlay,#cookie-hint,.dialog{display:none}#flashMp3Div audio,#audioDiv audio,#flashMp3Div,#audioDiv,#flashDiv{display:none}h1 .openTriangle{float:left;color:#888;font-size:20px;width:14px;text-align:left}@media only screen and (max-device-width :650px){h1 .openTriangle{height:1.2em}}.ad_topAndRect #header,.ad_topAndHalfpage #header{min-width:421px}.ad_topAndRect #result_container.webservice,.ad_topAndHalfpage #result_container.webservice{min-width:300px}.ad_topAndRect #outer_div,.ad_topAndHalfpage #outer_div{max-width:1230px;min-width:880px}.ad_LRectHalfpageRRectSkys #outer_div,.ad_LRectHalfpageRRectHalfpage #outer_div{max-width:1610px;min-width:1250px}.ad_leftAndRect #outer_div{max-width:1410px;min-width:1070px}.ad_leftAndRectWide #outer_div{max-width:1410px;min-width:1106px}.ad_leftAndRight #outer_div{max-width:1410px;min-width:910px}.ad_topAndRight #outer_div,.ad_translatorAndRight #outer_div,.ad_ad_underHeaderPremiumAndRight #outer_div,.ad_top #outer_div{min-width:738px}.ad_narrow #outer_div{min-width:300px}#banners_right,#banners_top,#banners_left{display:none}#mainlayout{position:relative;padding:0;min-height:100%;height:100%}.ad_top #mainlayout{padding-top:108px}.ad_topAndRight #mainlayout{padding-top:108px;padding-right:180px}.ad_topAndRect #mainlayout,.ad_topAndHalfpage #mainlayout{padding-top:108px;padding-right:320px}.ad_leftAndRect #mainlayout{padding-right:320px;padding-left:180px}.ad_LRectHalfpageRRectSkys #mainlayout,.ad_LRectHalfpageRRectHalfpage #mainlayout{padding-right:360px;padding-left:360px}.ad_leftAndRectWide #mainlayout{padding-right:356px;padding-left:180px}.ad_leftAndRight #mainlayout{padding-right:180px;padding-left:180px}.ad_translatorAndRight #mainlayout,.ad_underHeaderPremiumAndRight #mainlayout{padding-top:8px;padding-right:172px}#navi_bar_o{position:relative;height:34px;background-color:#67809a;margin-bottom:19px;border-bottom:1px solid #58728c}#navi_bar{position:relative;height:140px;overflow:hidden}#navi_bar_ul{line-height:18px;padding:0;height:35px;list-style-type:none;margin:0;position:relative;float:left;left:50%;display:block;width:auto}.ie7 #navi_bar_ul{display:block;float:left}.navi_li{font-size:14px;padding:0 10px 0 10px;margin:0;height:140px;color:#fff;vertical-align:middle;position:relative;right:50%;display:list-item;float:left}.ie7 .navi_li,.ie8 .navi_li{display:list-item;float:left}.navi_li>.i{position:rel ...
# </style>
# <style>.lQueryHeader__lingueeLogo {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/dl_Linguee_Logo.svg') !important;} .lMainNavbar__deeplLogoLink::before {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/DeepL_Logo_darkBlue_v2.svg') !important;} .dlTopBanner__content {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/banner/bg_orange_noise.png') !important;} .dlTopBanner__content::before {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/banner/bg_orange_noise.png') !important;} .dlTopBanner__content::after {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/banner/robot_with_girl.svg') !important;} .footer__social--twitter {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/icon_twitter_v2.svg') !important;} .footer__social--facebook {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/icon_fb_v2.svg') !important;} .footer__social--linkedin {background-image: URL('https://d1wigddrwdtsce.cloudfront.net/img5/icon_linkedin_v2.svg') !important;} </style>
# <script type="text/javascript">
# window.pageState={  interfaceLang:'FR',
#   langCodes:['FR','EN'],
#   sourceIsLang1:0,
#   mainFlag:'fr',
#   baseURL:'/francais-anglais',
#   sourceLang:'EN',
#   targetLang:'FR',
# };
# var cookie='569a3f88-2bb7-8bf4-de44-a8ecd0de46ff';
# var cookieLoginAuth='';
# var auxiliaryDictLang='deutsch-englisch';
# var numberQueriesSoFar=1;
# var currentYear=2022;
# var currentMonth='Jan';
# var currentDay=12;
# var currentHour=13;
# var currentMinute=47;
# var currentSecond=54;
# var hasCookies='0';
# var layout=4;
# var expertMode=0;
# var ipTestGroup=18;
# var adsInIFrames=0;
# var isStartPage=0;
# var isAboutPage=0;
# var newtestgroup='B';
# var numberCachedQueries=1;
# var timestampHead=new Date().getTime();
# var lingueeEncoding='latin-9';
# var sourceIsLang1=pageState.sourceIsLang1;;
# var langCodes=pageState.langCodes;
# var mainFlag=pageState.mainFlag;
# var baseURL=pageState.baseURL;
# var selectionBaseURL='/francais-anglais';
# var interfaceLang=pageState.interfaceLang;
# var queryFrequency=0;
# var tld='fr';
# var isLoggedIn=false;
# var statsEndpoint='prod';
# window.texts={
# 'acPressEnter': 'Appuyez sur Entrée pour chercher «&nbsp;QUERYHERE&nbsp;»'
# ,'acSearchFor': 'Rechercher &ldquo;QUERYHERE&rdquo;...'
# };
# var pressEnterText=texts['acPressEnter']; var acSearchForText=texts['acSearchFor'];
# var pastingLongStringsEnabled = false;
# var query = pageState.query = 'flower';
# var correctSpellingOfQuery = pageState.correctSpellingOfQuery = 'flower';
# pageState.casedQuery = 'flower';
# var numberPhrases = 0;
# var numberSentences = 27;
# var sourceFlag = 'gb';
# pageState.userTestGroups=[];
# var keyPressField=false;var queryFocussedOnKeyPress=false;var adPlacement="";var adSuppressed=false;var isApp=!!((window.pageState&&window.pageState.appInfo)||(/\b(app|android)[\-\.]/).test(document.domain)||(/\boverride-host=[^=\s]*(app|android)[\-\.]/).test(document.cookie)||document.cookie.search("app=")>=0);var isAppF=isApp;function queryIsMobilePhone(){return typeof window.matchMedia!="undefined"&&window.matchMedia("only screen and (max-device-width : 650px)").matches}function is_touch_device(){return"ontouchstart" in window||!!(navigator.msMaxTouchPoints)}var isMobilePhone=queryIsMobilePhone();var isMobilePhoneOrTablet=isApp||isMobilePhone||(typeof window.matchMedia!="undefined"&&window.matchMedia("only screen and (max-device-width : 799px)").matches&&is_touch_device());var isMobileNarrowDevice=typeof window.matchMedia!="undefined"&&window.matchMedia("only screen and (max-device-width : 767px)").matches;var isIPhone=typeof navigator.userAgent!="undefined"&&!!navigator.userAgent.match(/[\(\/](iPhone|iPod)/);var isIPad=typeof navigator.userAgent!="undefined"&&!!navigator.userAgent.match(/[\(\/](iPad)/);var isAndroid=typeof navigator.userAgent!="undefined"&&navigator.userAgent.indexOf("Android")!=-1;var isMobileLayout=isApp||isMobilePhone;var isStartPage=window.isStartPage||false;if(window.pageState){window.pageState.isMobileLayout=isMobileLayout;window.pageState.isApp=isApp;window.pageState.isAppF=isAppF}function adWidthClass(a){if(isMobileLayout){return""}if(a==""||a=="topAndRight"){return"ad_180"}else{if(a=="topAndRect"||a=="topAndHalfPage"||a=="leftAndRight"){return"ad_355"}else{if(a=="leftAndRect"||a=="leftAndRectWide"){return"ad_530"}else{if(a=="LRectHalfpageRRectSkys"||a=="LRectHalfpageRRectHalfpage"){return"ad_705"}else{return"ad_705"}}}}}function l_page_wrapper(b,d,a){var c=(is_touch_device())?" touch_device":" mouse_device";if(isIPhone){c+=" iphone ios"}else{if(isIPad){c+=" ipad ios"}else{if(isAndroid){c+=" android"}}}document.body.className=document.body.className+c;if(b){window.pageState.isAdsEnabled=!!b&&!d;adPlacement=correctAdPlacement(b);adSuppressed=d;if(adSuppressed&&(" "+document.body.className+" ").replace(/[\t\r\n\f]/g," ").indexOf(" startpage ")>-1){adPlacement=adPlacement+"_suppressed"}if(adPlacement){document.write(unescape("%3Cdiv id='l_page_wrapper' class='ad_"+adPlacement+" "+adWidthClass(adPlacement)+"'%3E"))}}}function correctAdPlacement(b){if(isMobileLayout){return""}var a=document.documentElement.clientWidth;var c=document.documentElement.clientHeight;if(b=="topAndHalfPage"){b="topAndHalfpage"}if(b=="LRectHalfpageRRectHalfpage"){if(a<1580){b="topAndRect"}}if(b=="topAndRect"||b=="topAndHalfpage"){if(c<870){b="leftAndRect"}else{if(a<=895){b="topAndRight"}}}if(b=="topAndRect"){b="leftAndRect"}if(b=="leftAndRect"){if(a<1200){b="leftAndRight"}}if(isMobileNarrowDevice&&b=="topAndRight"){b="top"}return b}function setVisible(b,a){var c=document.getElementById(b);if(c){c.style.display=(a)?"":"none"}}function isVisible(b){if(b==document){return true}if(!b){return false}if(!b.parentNode){return false}function a(c){if(c.display=="none"){return false}if(c.visibility=="hidden"){return false}}if(b.style&&a(b.style.visibility)){return false}if(window.getComputedStyle&&a(window.getComputedStyle(b,""))){return false}if(b.currentStyle&&a(b.currentStyle)){return false}return isVisible(b.parentNode)}function isChar(a){if((a>64&&a<91)||(a>96&&a<123)||a>191||a==0){return true}}var isIE=(/MSIE/).test(navigator.userAgent);var isFF=(/Firefox/).test(navigator.userAgent);var isChrome=(/Chrome/).test(navigator.userAgent)&&(/Google\ Inc/).test(navigator.vendor);var isSafari=(/Safari/).test(navigator.userAgent)&&(/Apple\ Computer/).test(navigator.vendor);var isOpera=(/Opera/).test(navigator.userAgent);var isEdge=(/Edge/).test(navigator.userAgent);var isIENewer=(/Trident/).test(navigator.userAgent);String.prototype.trim||(String.prototype.trim=function(){return this.replace(/^\s+|\s+$/g,"")});String.prototype.startsWith||(St ...
#
# </script>
# <script>
#                 if (!window.pageState.isMobileLayout) {
#                     var __loadScriptAsync = function(url) {
#                         var node = document.getElementsByTagName('script')[0];
#                         var script = document.createElement('script');
#                         script.type = "text/javascript";
#                         script.src = url;
#                         script.async = true;
#                         node.parentNode.insertBefore(script, node);
#                     };
#
#   __loadScriptAsync('//cdn.snigelweb.com/adengine/linguee.fr/loader.js');
# }
# </script>
# </link></meta></meta></meta></meta></meta></head>
# <body class="layout4 resultpage nonmobile design2019" id="body">
# <script>M.requireAsync(['DAP'], function (dap) { dap.sendPageView(dap.PAGEID_SEARCH); });</script>
# <script type="text/javascript">l_page_wrapper('LRectHalfpageRRectHalfpage',0,0);</script>
# <div id="ip_page_wrapper"><div id="ip_content_wrapper">
# <div class="tooltip" id="tooltip"> </div>
# <div id="selectionPopup">
# <ul class="selectionPopupActions">
# <li><a href="javascript:lingueeSearch()">Consulter Linguee</a></li>
# <li><a href="javascript:proposeTranslation()"> Proposer comme traduction pour "flower" </a></li>
# <li><a href="javascript:clipboardCopy()">Copier</a></li>
# </ul>
# <div class="selectionPopupFooter"></div>
# </div>
# <div class="il_FR il_FR" id="outer_div">
# <div id="mainlayout">
# <div id="banners_top">
# <div class="verticalAdText" id="banner_top">
# <div id="adngin-top_tablet_leaderboard-0"></div>
# </div>
# </div>
# <div id="snigel_ads_right" style="  top: 0;right: 0; position: absolute;text-align: center;">
# <div id="adngin-right_side_top-0" style="margin-bottom:10px;"></div>
# <div id="adngin-right_side_bottom_sticky-0"></div>
# </div>
# <div id="snigel_ads_left" style=" top: 0; left: 0; position: absolute; text-align: center;">
# <div id="adngin-left_side_top-0" style="margin-bottom:10px;"></div>
# <div id="adngin-left_side_bottom_sticky-0"></div>
# </div>
# <script type="text/javascript">
#                              var googletag = googletag || {};
#                              googletag.cmd = googletag.cmd || [];
#                          </script>
# <script type="text/javascript">
#                              var brosersAndVersions = navigator.userAgent.match(/(\w+)\/([0-9.]+)/g);
#                              var browsers = {};
#                              for (var i = 0; i < brosersAndVersions.length; ++i) {
#                                  var arr = brosersAndVersions[i].split("/");
#                                  browsers[arr[0]] = parseFloat(arr[1]);
#                              }
#
#                              var offset = function(el) {
#                                  var rect = el.getBoundingClientRect(), scrollLeft = window.pageXOffset || document.documentElement.scrollLeft, scrollTop = window.pageYOffset || document.documentElement.scrollTop;
#                                  return { top: rect.top + scrollTop, left: rect.left + scrollLeft };
#                              };
#
#                              var main = window.getComputedStyle(document.getElementById('mainlayout'));
#                              var outer_div = offset(document.getElementById('outer_div'));
#                              var mainPosition = offset(document.getElementById('mainlayout'));
#                              var scrollListener = function(main, element, side) {
#                                  var stickyPos = document.getElementById(element), offsetDiv = offset(stickyPos);
#                                  stickyPos.style.width = main;
#                                  window.addEventListener('scroll', function() {
#                                      var topDistance = window.scrollY;
#                                      if ($("#body").hasClass("parallax")) { topDistance = Math.abs(offset(document.getElementById('mainlayout')).top); }
#
#                                      if (offsetDiv.top <= 0) {
#                                        offsetDiv = offset(stickyPos);s
#                                        stickyPos.style.position = 'relative';
#                                        stickyPos.style.top = '0px';
#                                        stickyPos.style[side] = '0px';
#                                      } else if (topDistance >= offsetDiv.top) {
#                                        stickyPos.style.position = 'fixed';
#                                        if ($("#body").hasClass("parallax")) {
#                                          if (browsers["Safari"] >= 601) {
#                                            stickyPos.style.top = '0px';
#                                          } else {
#                                            stickyPos.style.top = topDistance + 'px';
#                                          }
#                                          stickyPos.style[side] = '0px';
#                                        } else {
#                                          stickyPos.style[side] = (outer_div.left + mainPosition.left) / 2 + 'px';
#                                        }
#                                      } else {
#                                          stickyPos.style.position = 'relative';
#                                          stickyPos.style.top = '0px';
#                                          stickyPos.style[side] = '0px';
#                                      }
#                                  }, true);
#                              };
#
#                              window.addEventListener('adnginLoaderReady', function () {
#                                adngin.queue.push(function () {
#                                  document.getElementById('adngin-right_side_top-0').style.width = main.getPropertyValue('padding-right');
#                                  document.getElementById('adngin-left_side_top-0').style.width = main.getPropertyValue('padding-left');
#                                  googletag.cmd.push(function () {
#                                    googletag.pubads().addEventListener('slotRenderEnded', function () {
#                                      document.getElementById('snigel_ads_right').style.top = ((window.innerWidth > 767 && window.innerWidth < 896) ? 108 : 0) + 'px';
#                                      scrollListener(main.getPropertyValue('padding-left'), 'adngin-left_side_bottom_sticky-0', 'left');
#                                      scrollListener(main.getPropertyValue('padding-right'), 'adngin-right_side_bottom_sticky-0', 'right');
#                                    });
#                                  });
#                                });
#                              });
#                          </script>
# <div class="mainpadding" id="maindiv">
# <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600" rel="stylesheet"/>
# <nav class="lMainNavbar wide_in_main">
# <div class="lMainNavbar__left">
# <a class="lMainNavbar__deeplLogoLink" href="https://www.DeepL.com/translator">DeepL</a>
# <a class="lMainNavbar__translatorLink" href="https://www.DeepL.com/translator">Traducteur</a>
# <a class="lMainNavbar__lingueeLink is-active" href="/">Linguee</a>
# </div>
# <div class="lMainNavbar__right">
# <div class="lMainNavbar__buttonContainer">
# <div class="lMainNavbar__uiLangChooser"><button>FR</button></div>
# <div class="lMainNavbar__burgerButton"><button onclick="window.lMainNavbar.toggleBurgerMenu()">Open menu</button></div>
# </div>
# </div></nav>
# <template id="template_navPopup" style="display:none"> <div class="lNavPopup"> <div class="lNavPopup__overlay"></div> <div class="lNavPopup__window"> <button class="lNavPopup__closeButton"></button> <nav class="lNavPopup__navLinks"> <a class="lNavPopup__navLink lNavPopup__navLink--translator" href="https://www.DeepL.com/translator">Traducteur</a> <p class="lNavPopup__navLink-desc">Traduisez des textes avec la meilleure technologie de traduction automatique au monde, développée par les créateurs de Linguee.</p> <a class="lNavPopup__navLink lNavPopup__navLink--linguee" href="/">Linguee</a> <p class="lNavPopup__navLink-desc">Recherchez des traductions de mots et de phrases dans des dictionnaires bilingues, fiables et exhaustifs et parcourez des milliards de traductions en ligne.</p> <a class="lNavPopup__navLink" href="https://www.DeepL.com/blog.html">Blog</a> <a class="lNavPopup__navLink" href="https://www.DeepL.com/press.html">Informations presse</a> </nav> <div class="lNavPopup__appsSection"> <h2>Applications Linguee</h2> <a class="lNavPopup__appStoreLink appStoreLink" href="https://itunes.apple.com/de/app/id338225335?mt=8" target="_blank"><div class="AppStoreBadge appstore-logo"> </div></a> <a class="lNavPopup__appStoreLink playStoreLink" href="https://play.google.com/store/apps/details?id=com.linguee.linguee&amp;referrer=utm_source%3Dlinguee%26utm_medium%3Dunknown%26utm_campaign%3Dstart" target="_blank"><div class="PlayStoreBadge"> </div></a> </div> <script>
# 			window.$$initInstance && window.$$initInstance(function(node){
# 				function doClose(){
# 					node.parentNode.removeChild(node);
# 					node.doClose = undefined;
# 				}
# 				node.querySelector('.lNavPopup__closeButton').addEventListener('click', doClose);
# 				node.querySelector('.lNavPopup__overlay').addEventListener('click', doClose);
# 				node.doClose = doClose;
# 			});
# 			</script>
# </div>
# </div>
# </template>
# <script>
# 	window.lMainNavbar = {
# 	  toggleBurgerMenu: function(){
# 		  if (this._popupNode && this._popupNode.doClose){ this._popupNode.doClose(); this._popupNode = undefined; }
# 		  else this._popupNode = UI_Tools.createTemplateInstance('#template_navPopup', 'body');
# 		}
# 	};
# </script>
# <div class="wide_in_main l_header" id="header">
# <form accept-charset="utf-8" action="/francais-anglais/search" id="form1" method="get" name="bigform" onsubmit="return lingueeSubmitForm();">
# <div class="lQueryHeader">
# <a class="lQueryHeader__lingueeLogo" href="/">Linguee</a>
# <div class="lQueryHeader__langSelector">
# <select id="langPair" name="source">
# <option selected="selected" value="auto">[fr] français &lt;-&gt; [gb] anglais</option>
# <option value="francais">[fr] français ---&gt; [gb] anglais</option>
# <option class="dir_last" value="anglais">[gb] anglais ---&gt; [fr] français</option>
# <option value="/francais-allemand">[fr] français &lt;-&gt; [de] allemand</option>
# <option value="/francais-espagnol">[fr] français &lt;-&gt; [es] espagnol</option>
# <option value="/francais-portugais">[fr] français &lt;-&gt; [pt] portugais</option>
# <option value="/francais-italien">[fr] français &lt;-&gt; [it] italien</option>
# <option value="/francais-neerlandais">[fr] français &lt;-&gt; [nl] néerlandais</option>
# <option value="/francais-polonais">[fr] français &lt;-&gt; [pl] polonais</option>
# <option value="/francais-suedois">[fr] français &lt;-&gt; [se] suédois</option>
# <option value="/francais-danois">[fr] français &lt;-&gt; [dk] danois</option>
# <option value="/francais-finnois">[fr] français &lt;-&gt; [fi] finnois</option>
# <option value="/francais-grec">[fr] français &lt;-&gt; [gr] grec</option>
# <option value="/francais-tcheque">[fr] français &lt;-&gt; [cz] tchèque</option>
# <option value="/francais-roumain">[fr] français &lt;-&gt; [ro] roumain</option>
# <option value="/francais-hongrois">[fr] français &lt;-&gt; [hu] hongrois</option>
# <option value="/francais-slovaque">[fr] français &lt;-&gt; [sk] slovaque</option>
# <option value="/francais-bulgare">[fr] français &lt;-&gt; [bg] bulgare</option>
# <option value="/francais-slovene">[fr] français &lt;-&gt; [si] slovène</option>
# <option value="/francais-lituanien">[fr] français &lt;-&gt; [lt] lituanien</option>
# <option value="/francais-letton">[fr] français &lt;-&gt; [lv] letton</option>
# <option value="/francais-estonien">[fr] français &lt;-&gt; [ee] estonien</option>
# <option value="/francais-maltais">[fr] français &lt;-&gt; [mt] maltais</option>
# <option value="moreLanguages">Plus de langues</option>
# </select>
# </div>
# <div class="letterHelp lQueryHeader__letterHelp"><a href="javascript:addLetter('à');">à</a><a href="javascript:addLetter('â');">â</a><a href="javascript:addLetter('é');">é</a><a href="javascript:addLetter('è');">è</a><a href="javascript:addLetter('ê');">ê</a><a href="javascript:addLetter('ë');">ë</a><a href="javascript:addLetter('ï');">ï</a><a href="javascript:addLetter('î');">î</a><a href="javascript:addLetter('ô');">ô</a><a href="javascript:addLetter('ù');">ù</a><a href="javascript:addLetter('û');">û</a><a href="javascript:addLetter('ç');">ç</a><a href="javascript:addLetter('œ');">œ</a><a href="javascript:addLetter('æ');">æ</a></div>
# <script type="text/javascript">var letterHelp={gb:'àâéèêëïîôùûçœæ',de:'äöüßàâéèêëïîôùûçœæ',es:'áéíóúüñàâèêëïîôùûçœæ',pt:'áàãâéêíóõôúçèëïîùûœæ',fr:'àâéèêëïîôùûçœæ'}</script>
# <div class="lQueryHeader__input_container">
# <input autocapitalize="off" autocomplete="off" autocorrect="off" autofocus="" id="queryinput" maxlength="60" name="query" spellcheck="false" tabindex="1" type="text" value="flower"/>
# <button alt="Rechercher dans le dictionnaire français-anglais" type="submit"></button><div class="lQueryHeader__ac_container"></div></div>
# <div class="l_header__mobileLangButton" id="small_prefs"><span>FR</span><hr/><span>EN</span></div>
# </div><!--query_wrapper-->
# </form>
# </div> <!-- /header -->
# <script type="text/javascript">
# var LTexts = {button_audio: 'Écouter',button_search: 'Chercher',no_examples: 'Aucun exemple de sources externes.'}
# afterHeader()
# </script>
# <div id="lingueecontent">
# <div id="phraseeditAjaxDelay"></div>
# <div class="innercontent">
# <!-- DeepL Search Banner -->
# <div class="l_deepl_ad_container wide_in_main" style="display:none">
# <div class="l_deepl_ad__bg">
# </div>
# <div class="l_deepl_ad__content_container">
# <div class="l_deepl_ad_headercontainer">
# <div class="l_deepl_ad_header">Utilisez DeepL Traducteur pour traduire instantanément textes et documents</div>
# <div class="l_deepl_ad_header__mobile">Essayez DeepL Traducteur</div>
# </div>
# <div class="l_deepl_ad_bodycontainer">
# <div class="lmt__textarea_separator lmt__textarea_separator--left">
# <div class="lmt__textarea_separator__vertical_line"></div>
# <div class="lmt__textarea_separator__arrow"></div>
# <div class="lmt__textarea_separator__border_inner"></div>
# <div class="lmt__textarea_separator__border_outer"></div>
# <div class="lmt__textarea_separator__busy"></div>
# </div>
# <div class="l_deepl_ad__querytext lmt__textarea">flower</div>
# <div class="l_deepl_ad__copyListContainer">
# <ul>
# <li>Traduction en temps réel</li>
# <li>Meilleure qualité au monde</li>
# <li>Documents chargeables en « glisser-déposer »</li>
# </ul>
# <div class="l_deepl_ad__ctaButton" href="https://deepl.com">Essayer</div>
# </div>
# </div>
# </div>
# </div>
# <div id="dictionary">
# <h1 class="dict_headline_for_0 bothsides wide_in_main"><div class="openTriangle"> ▾</div>Dictionnaire anglais-français</h1>
# <div class="isForeignTerm" data-source-lang="EN"><div class="exact"><div class="lemma featured" wt="101"><div><h2 class="line lemma_desc" lid="EN:flower16102"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower.html" rel="nofollow">flower</a> <a class="audio" id="EN_US/60/608f0b988db4a96066af7dd8870de96c-100" onclick='playSound(this,"EN_US/60/608f0b988db4a96066af7dd8870de96c-100","anglais américain","EN_UK/60/608f0b988db4a96066af7dd8870de96c-100","anglais britannique");'></a> <span class="tag_wordtype">nom</span></span> <span class="tag_forms forms_plural"> (<span class="tag_formname">pluriel: </span><span class="tag_s"><a class="formLink" href="/anglais-francais/traduction/flowers.html" rel="nofollow">flowers</a></span>)</span><span class="dash">—</span></h2><div class="lemma_content"><div class="meaninggroup sortablemg" gid="0"><div class="translation_lines"><div class="translation sortablemg featured"><h3 class="translation_desc"><span bid="10000703605" class="tag_trans" lid="FR:fleur17529"><a class="dictLink featured" href="/francais-anglais/traduction/fleur.html" id="dictEntry10000703605">fleur</a> <span class="tag_type" title="nom, féminin">f</span> <a class="audio" id="FR/1e/1ea31d12c145f5b54332e6ae2bb04ab7-107" onclick='playSound(this,"FR/1e/1ea31d12c145f5b54332e6ae2bb04ab7-107","français");'></a><a class="expand_i"></a></span><!--tag_trans--> <span class="tag_forms forms_plural"> (<span class="tag_formname">pluriel: </span><span class="tag_t"><a class="formLink" href="/francais-anglais/traduction/fleurs.html" rel="nofollow">fleurs</a> <span class="tag_type">f</span></span>)</span></h3><!--translation_desc--><!-- editorial isFeatured 1 inType 0 allowFeatured 1 available: 2 -->
# <div class="example_lines"><div class="example line" sid="18369"><span class="tag_e"><span class="tag_s">She got flowers for her birthday.</span> <span class="dash">—</span> <span class="tag_t">Elle a reçu des fleurs pour son anniversaire.</span><span class="tag_e_end"></span></span></div><div class="example line" sid="31987"><span class="tag_e"><span class="tag_s">A layer of frost blanketed the flowers.</span> <span class="dash">—</span> <span class="tag_t">Une couche de givre recouvrait les fleurs.</span><span class="tag_e_end"></span></span></div></div></div>
# </div><!--translation_lines-->
# </div><!--meaninggroup-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma" wt="200"><div><h2 class="line lemma_desc" lid="EN:flower16102"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower.html" rel="nofollow">flower</a> <a class="audio" id="EN_US/60/608f0b988db4a96066af7dd8870de96c-200" onclick='playSound(this,"EN_US/60/608f0b988db4a96066af7dd8870de96c-200","anglais américain","EN_UK/60/608f0b988db4a96066af7dd8870de96c-200","anglais britannique");'></a> <span class="tag_wordtype">verbe</span></span> <span class="tag_forms forms_verb"> (<span class="tag_s"><a class="formLink" href="/anglais-francais/traduction/flowered.html">flowered</a></span>, <span class="tag_s"><a class="formLink" href="/anglais-francais/traduction/flowered.html">flowered</a></span>)</span><span class="dash">—</span></h2><div class="lemma_content"><div class="meaninggroup sortablemg" gid="0"><div class="translation_lines"><div class="translation sortablemg"><h3 class="translation_desc"><span bid="10000703620" class="tag_trans" lid="FR:fleurir49223"><a class="dictLink" href="/francais-anglais/traduction/fleurir.html" id="dictEntry10000703620">fleurir</a> <span class="tag_type" title="verbe">v</span> <a class="audio" id="FR/ce/ce9a6e6337661a9b5428e3d25b0f9585-200" onclick='playSound(this,"FR/ce/ce9a6e6337661a9b5428e3d25b0f9585-200","français");'></a><a class="expand_i"></a></span><!--tag_trans--></h3><!--translation_desc--><!-- editorial isFeatured 0 inType 0 allowFeatured 1 available: 0 -->
# </div>
# </div><!--translation_lines-->
# </div><!--meaninggroup-->
# </div><!--lemma_content--></div></div><!--lemma-->
# </div><!--exact--><div class="example_lines inexact"><h3>Exemples :</h3><div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+shop.html" lid="EN:flower#shop7798"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+shop.html">flower shop</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/f7/f764977216f5cca7e3ffa8e85947107e-101" onclick='playSound(this,"EN_UK/f7/f764977216f5cca7e3ffa8e85947107e-101","anglais britannique","EN_US/f7/f764977216f5cca7e3ffa8e85947107e-100","anglais américain");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10000787665" class="tag_trans" lid="FR:fleuriste3994"><a class="dictLink" href="/francais-anglais/traduction/fleuriste.html" id="dictEntry10000787665">fleuriste</a> <span class="tag_type" title="nom, masculin">m</span> <a class="audio" id="FR/91/91cc8d8405bff4764678cd38ab5e5a99-106" onclick='playSound(this,"FR/91/91cc8d8405bff4764678cd38ab5e5a99-106","français");'></a><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+arrangement.html" lid="EN:flower#arrangement63971"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+arrangement.html">flower arrangement</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/ee/eec367027038c7b7861ba42ef3fb2589-101" onclick='playSound(this,"EN_UK/ee/eec367027038c7b7861ba42ef3fb2589-101","anglais britannique","EN_US/ee/eec367027038c7b7861ba42ef3fb2589-100","anglais américain");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002599249" class="tag_trans" lid="FR:composition#florale58847"><a class="dictLink" href="/francais-anglais/traduction/composition+florale.html" id="dictEntry10002599249">composition florale</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# <span class="sep">·</span> </div>
# <div class="translation sortablemg"><div class="translation_desc"><span bid="10003062296" class="tag_trans" lid="FR:arrangement#floral6324"><a class="dictLink" href="/francais-anglais/traduction/arrangement+floral.html" id="dictEntry10003062296">arrangement floral</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="102"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+seeds.html" lid="EN:flower#seeds45156"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+seeds.html">flower seeds</a> <span class="tag_type" title="nom, pluriel">pl</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005151446" class="tag_trans" lid="FR:semences#de#fleurs55070"><a class="dictLink" href="/francais-anglais/traduction/semences+de+fleurs.html" id="dictEntry10005151446">semences de fleurs</a> <span class="tag_type" title="nom, pluriel, féminin">pl f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="expandable"><div class="versionShort"><a class="expandM" onclick="expandAnim(this)"></a></div><div class="versionLong"><div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+market.html" lid="EN:flower#market29543"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+market.html">flower market</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/58/58a3b21c3c157ab7f1b30b4b066604d9-100" onclick='playSound(this,"EN_UK/58/58a3b21c3c157ab7f1b30b4b066604d9-100","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002727957" class="tag_trans" lid="FR:march##aux#fleurs43527"><a class="dictLink" href="/francais-anglais/traduction/march%C3%A9+aux+fleurs.html" id="dictEntry10002727957">marché aux fleurs</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+industry.html" lid="EN:flower#industry64106"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+industry.html">flower industry</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004701624" class="tag_trans" lid="FR:industrie#floricole57176"><a class="dictLink" href="/francais-anglais/traduction/industrie+floricole.html" id="dictEntry10004701624">industrie floricole</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+pattern.html" lid="EN:flower#pattern528"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+pattern.html">flower pattern</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005473813" class="tag_trans" lid="FR:motif#floral19154"><a class="dictLink" href="/francais-anglais/traduction/motif+floral.html" id="dictEntry10005473813">motif floral</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# <span class="sep">·</span> </div>
# <div class="translation sortablemg"><div class="translation_desc"><span bid="10004624916" class="tag_trans" lid="FR:motif#fleuri41864"><a class="dictLink" href="/francais-anglais/traduction/motif+fleuri.html" id="dictEntry10004624916">motif fleuri</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# <span class="sep">·</span> </div>
# <div class="translation sortablemg"><div class="translation_desc"><span bid="10005447882" class="tag_trans" lid="FR:dessin#floral3170"><a class="dictLink" href="/francais-anglais/traduction/dessin+floral.html" id="dictEntry10005447882">dessin floral</a> <span class="tag_type" title="nom, masculin">m</span></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+basket.html" lid="EN:flower#basket3442"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+basket.html">flower basket</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/90/90ecaa638bf989ac3547a7638fa2b313-100" onclick='playSound(this,"EN_UK/90/90ecaa638bf989ac3547a7638fa2b313-100","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004674379" class="tag_trans" lid="FR:panier#fleuri20085"><a class="dictLink" href="/francais-anglais/traduction/panier+fleuri.html" id="dictEntry10004674379">panier fleuri</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+meadow.html" lid="EN:flower#meadow39011"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+meadow.html">flower meadow</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005159277" class="tag_trans" lid="FR:prairie#fleurie15841"><a class="dictLink" href="/francais-anglais/traduction/prairie+fleurie.html" id="dictEntry10005159277">prairie fleurie</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/cotton+flower.html" lid="EN:cotton#flower46051"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/cotton+flower.html">cotton flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005012201" class="tag_trans" lid="FR:fleur#de#coton48001"><a class="dictLink" href="/francais-anglais/traduction/fleur+de+coton.html" id="dictEntry10005012201">fleur de coton</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+nectar.html" lid="EN:flower#nectar26403"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+nectar.html">flower nectar</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004843734" class="tag_trans" lid="FR:nectar#de#fleur15353"><a class="dictLink" href="/francais-anglais/traduction/nectar+de+fleur.html" id="dictEntry10004843734">nectar de fleur</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/zucchini+flower.html" lid="EN:zucchini#flower13954"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/zucchini+flower.html">zucchini flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002904664" class="tag_trans" lid="FR:fleur#de#courgette24221"><a class="dictLink" href="/francais-anglais/traduction/fleur+de+courgette.html" id="dictEntry10002904664">fleur de courgette</a> <span class="tag_type" title="nom, féminin">f</span></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# ...
# </div></td>
# </tr>
# <tr class="" id="row_0_5325080629_0">
# <td class="sentence left"><div class="wrap">
# It is a deli<b class="b1">ca</b><b class="b2">t</b><b class="b3">e</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">a</b><b class="b2">n</b><b class="b1">d </b>we all want it <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">to be a success.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20000906+ITEMS+DOC+XML+V0//EN&amp;amp;language=EN" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Il s'agit <b class="b1">d'</b><b class="b2">une </b><b class="b3">jeun</b><b class="b4">e </b><b class="b5">pousse</b><b class="b4"> e</b><b class="b3">t no</b><b class="b2">us v</b><b class="b1">ou</b>lons tous <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">qu'elle prospère.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20000906+ITEMS+DOC+XML+V0//FR&amp;amp;language=FR" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8767649588_0">
# <td class="sentence left"><div class="wrap">
# If the crop has been tryin<b class="b1">g </b><b class="b2">t</b><b class="b3">o</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">f</b><b class="b2">o</b><b class="b1">r </b>four or more days but cannot because of the lygus pressure, the insecticide should reduce the lygus to a level that will a<b class="b1">ll</b><b class="b2">o</b><b class="b3">w</b><b class="b4"> </b><b class="b5">flowering</b>. <div class="source_url_spacer">sca-fcc.ca</div>
# <div class="source_url"><a href="http://www.sca-fcc.ca/newsletters/en/express/articles/20100709_e.asp" rel="noopener noreferrer" target="_blank">sca-fcc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Si les plants s'ef<b class="b1">fo</b><b class="b2">rcent</b><b class="b3"> de</b><b class="b4"> fleurir </b><b class="b3">dep</b><b class="b2">uis q</b><b class="b1">ua</b>tre jours ou plus mais n'y parviennent pas en raison de l'action des punaises, l'insecticide devrait réduire la population d'insectes à un nombr<b class="b1">e </b><b class="b2">propi</b><b class="b3">ce </b><b class="b4">à l</b><b class="b5">a floraison</b>. <div class="source_url_spacer">sca-fcc.ca</div>
# <div class="source_url"><a href="http://www.sca-fcc.ca/newsletters/fr/express/articles/20100709_f.asp" rel="noopener noreferrer" target="_blank">sca-fcc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_1626665108_0">
# <td class="sentence left"><div class="wrap">
# Some honey drops conta<b class="b1">in</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">flower</b>. <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/en-EN/help/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# <div class="shortened_begin2">Certaines gouttes de</div>
# <span class="placeholder_begin2">[...] </span>
#  miel cont<b class="b1">ie</b><b class="b2">nnent</b><b class="b3"> un</b><b class="b4">e fleur</b>. <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/fr-FR/aide/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_3777300801_0">
# <td class="sentence left"><div class="wrap">
# I only recognise the li<b class="b1">tt</b><b class="b2">l</b><b class="b3">e</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">w</b><b class="b2">i</b><b class="b1">th</b> the circle of <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">stars around it from a brand of toilet paper.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20090402+ITEMS+DOC+XML+V0//EN&amp;amp;language=EN" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Je ne conn<b class="b1">ai</b><b class="b2">s la </b><b class="b3">pet</b><b class="b4">ite</b><b class="b5"> fleur </b><b class="b4">ent</b><b class="b3">our</b><b class="b2">ée d'</b><b class="b1">un</b> cercle <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">d'étoiles que grâce à une marque de papier hygiénique.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20090402+ITEMS+DOC+XML+V0//FR&amp;amp;language=FR" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_465270090_0">
# <td class="sentence left"><div class="wrap">
# <div class="shortened_begin2">How many times did his disciples or the people see Jesus</div>
# <span class="placeholder_begin2">[...] </span>
#  caressing a bird <b class="b1">or</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">flower</b><b class="b4">,</b><b class="b3"> </b><b class="b2">a</b><b class="b1">nd</b> blessing them all. <div class="source_url_spacer">das-dritte-testament.com</div>
# <div class="source_url"><a href="http://das-dritte-testament.com/E/CapII.htm" rel="noopener noreferrer" target="_blank">das-dritte-testament.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# <div class="shortened_begin2">A maintes reprises les disciples et les gens virent Jésus</div>
# <span class="placeholder_begin2">[...] </span>
#  caresser un o<b class="b1">is</b><b class="b2">eau o</b><b class="b3">u u</b><b class="b4">ne</b><b class="b5"> fleur </b><b class="b4">et</b><b class="b3"> bé</b><b class="b2">nissa</b><b class="b1">nt</b> tout. <div class="source_url_spacer">das-dritte-testament.com</div>
# <div class="source_url"><a href="http://das-dritte-testament.com/F/CapII.htm" rel="noopener noreferrer" target="_blank">das-dritte-testament.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_4451070132_0">
# <td class="sentence left"><div class="wrap">
# <div class="shortened_begin2">On the left</div>
# <span class="placeholder_begin2">[...] </span>
#  side, you'll fi<b class="b1">nd</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">w</b><b class="b2">h</b><b class="b1">er</b>e the bee flies <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">around when you score points.</div>
# <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/en-EN/help/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Sur la gauche s<b class="b1">e </b><b class="b2">trouv</b><b class="b3">e u</b><b class="b4">ne</b><b class="b5"> fleur </b><b class="b4">au</b><b class="b3">tou</b><b class="b2">r de </b><b class="b1">la</b>quelle <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">l'abeille vole lorsque vous marquez des points.</div>
# <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/fr-FR/aide/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8461737982_0">
# <td class="sentence left"><div class="wrap">
# The t<b class="b1">ul</b><b class="b2">i</b><b class="b3">p</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">r</b><b class="b2">e</b><b class="b1">se</b>mbles a turban, and <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">that is why the Turkish name for tulip is "Tuliband".</div>
# <div class="source_url_spacer">euro-cordiale.lu</div>
# <div class="source_url"><a href="http://www.euro-cordiale.lu/compro/files/EN/D/D3_33.pdf" rel="noopener noreferrer" target="_blank">euro-cordiale.lu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# L<b class="b3">a </b><b class="b4">fleur</b><b class="b3"> d'</b><b class="b2">une t</b><b class="b1">uli</b><b class="b2">pe rappelle un</b><b class="b1"> t</b>urban, <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">c'est pourquoi le nom turc de la tulipe est « Tuliband ».</div>
# <div class="source_url_spacer">euro-cordiale.lu</div>
# <div class="source_url"><a href="http://www.euro-cordiale.lu/compro/files/FR/D/D3_33.pdf" rel="noopener noreferrer" target="_blank">euro-cordiale.lu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
#
#  <!-- /result_table -->
# </div> <!-- /result_div -->
# </div>
# <!-- /result_container -->
# </div><!--innercontent-->
# </div><!--lingueecontent-->
# <div class="footer" id="footer">
# <div id="attribution">
# </div>
# <div id="currently_searched">Requêtes en cours :
# <a href="/francais-anglais/traduction/art+de+vivre.html">art de vivre</a>, <a href="/anglais-francais/traduction/labour+intensive.html">labour intensive</a>, <a href="/francais-anglais/traduction/je+vous+souhaite+une+tr%C3%A8s+bonne+ann%C3%A9e.html">je vous souhaite une très bonne année</a>, <a href="/anglais-francais/traduction/business+purpose.html">business purpose</a>, <a href="/francais-anglais/traduction/gare.html">gare</a>, <a href="/anglais-francais/traduction/luxembourg.html">luxembourg</a>, <a href="/francais-anglais/traduction/de+fa%C3%A7on+permanente.html">de façon permanente</a>, <a href="/anglais-francais/traduction/sensing.html">sensing</a>, <a href="/francais-anglais/traduction/aurait+pu.html">aurait pu</a>, <a href="/anglais-francais/traduction/hectic.html">hectic</a>, <a href="/francais-anglais/traduction/pendant+cette+p%C3%A9riode.html">pendant cette période</a>, <a href="/anglais-francais/traduction/pulley.html">pulley</a>, <a href="/francais-anglais/traduction/collation.html">collation</a>, <a href="/anglais-francais/traduction/point+of+care.html">point of care</a>, <a href="/francais-anglais/traduction/il+va+bien.html">il va bien</a></div>
# <div id="important_terms">Requête la plus fréquente dans le dictionnaire français :
#  <a href="/french-english/topfrench/1-200.html">1-200</a>, <a href="/french-english/topfrench/201-1000.html">-1k</a>, <a href="/french-english/topfrench/1001-2000.html">-2k</a>, <a href="/french-english/topfrench/2001-3000.html">-3k</a>, <a href="/french-english/topfrench/3001-4000.html">-4k</a>, <a href="/french-english/topfrench/4001-5000.html">-5k</a>, <a href="/french-english/topfrench/5001-7000.html">-7k</a>, <a href="/french-english/topfrench/7001-10000.html">-10k</a>
# , <a href="/french-english/topfrench/10001-20000.html">-20k</a>, <a href="/french-english/topfrench/20001-40000.html">-40k</a>, <a href="/french-english/topfrench/40001-100000.html">-100k</a>, <a href="/french-english/topfrench/100001-200000.html">-200k</a>, <a href="/french-english/topfrench/200001-500000.html">-500k</a>, <a href="/french-english/topfrench/500001-2200000.html">-1000k</a><br/>
# Requête la plus fréquente dans le dictionnaire anglais :
#  <a href="/english-french/topenglish/1-200.html">1-200</a>, <a href="/english-french/topenglish/201-1000.html">-1k</a>, <a href="/english-french/topenglish/1001-2000.html">-2k</a>, <a href="/english-french/topenglish/2001-3000.html">-3k</a>, <a href="/english-french/topenglish/3001-4000.html">-4k</a>, <a href="/english-french/topenglish/4001-5000.html">-5k</a>, <a href="/english-french/topenglish/5001-7000.html">-7k</a>, <a href="/english-french/topenglish/7001-10000.html">-10k</a>
# , <a href="/english-french/topenglish/10001-20000.html">-20k</a>, <a href="/english-french/topenglish/20001-40000.html">-40k</a>, <a href="/english-french/topenglish/40001-100000.html">-100k</a>, <a href="/english-french/topenglish/100001-200000.html">-200k</a>, <a href="/english-french/topenglish/200001-500000.html">-500k</a>, <a href="/english-french/topenglish/500001-2200000.html">-1000k</a><br/>
# </div>
# <div class="footer__inner"><nav class="footer__nav" id="footerNav"><a href="https://www.linguee.com/english-french/translation/flower.html" onclick="differentDomain(this)"><span>Linguee</span> in English</a>
# <a href="/francais-anglais/page/login.php" rel="nofollow">Connexion</a>
# <a href="/francais-anglais/page/imprint.php" rel="nofollow">Mentions légales</a>
# <a href="/francais-anglais/page/termsAndConditions.php" rel="nofollow">CGU</a>
# <a href="/francais-anglais/page/privacy.php" rel="nofollow">Déclaration de confidentialité</a></nav><div class="footer__socials"><a class="footer__social footer__social--twitter" href="https://twitter.com/DeepLcom" rel="noopener" target="_blank" title="Twitter"></a><a class="footer__social footer__social--facebook" href="https://www.facebook.com/DeepLcom/" rel="noopener" target="_blank"></a><a class="footer__social footer__social--linkedin" href="https://www.linkedin.com/company/linkedin-com-company-deepl/" rel="noopener" target="_blank"></a></div></div></div> <!-- /footer -->
# </div><!--maindiv--></div><!--mainlayout-->
# <div class="dialog" id="voteDownReasonDiv">
# <a class="button_close" onclick="forgetVoteDown()"></a>
# <b>Veuillez choisir une raison pour justifier votre évaluation de la traduction :</b>
# <ul><li id="vdBadExample"><a onclick="vdBadExample()">Cet exemple ne correspond à la traduction ci-dessus.</a></li>
# <li id="vdWrongBoldWords"><a onclick="vdWrongBoldWords()">Les mots surlignés ne correspondent pas.</a></li>
# <li id="vdDoesNotFitForQuery"><a onclick="vdDoesNotFitForQuery()">Ce résultat ne correspond pas à ma recherche.</a></li>
# <li id="vdShouldNotBeCombined"><a onclick="vdShouldNotBeCombined()">Cet exemple ne correspond pas à l'entrée en orange.</a></li>
# <li id="vdBadTranslation"><a onclick="vdBadTranslation()">La traduction est fausse ou de mauvaise qualité.</a></li>
# </ul>
# </div>
# <div class="dialog" id="voteThankYouDiv">
# <a class="button_close" onclick='jQuery("#voteThankYouDiv").fadeOut("fast")'></a>
# Merci d'avoir donné votre avis sur cette traduction !<br/> Vous contribuez ainsi à l'amélioration de notre service.
# </div>
# <link href="https://d1wigddrwdtsce.cloudfront.net/5_f079dcc8/css3/style4-late.min.css.g" rel="stylesheet" type="text/css"/><script src="https://d1wigddrwdtsce.cloudfront.net/5_f079dcc8/javascript/linguee4-all-late.min.js.g" type="text/javascript"></script>
# <script type="text/javascript">callDocumentReady();</script>
# <script type="text/javascript">
#   abpFormat='rectangle';
#   //if (document.documentElement.clientWidth*document.documentElement.clientHeight*0.15>=600*300) {
#   //  abpFormat='halfpage';
#   //}
# </script>
# <script type="text/javascript">
# if (isIE || isEdge || isIENewer) { window.performance=null; }
# </script>
# <script type="text/javascript">
# </script>
# </div></div>
# <script type="text/javascript">l_page_wrapper_close();</script>
# <div id="flashMp3Div"></div>
# <img border="0" height="1" src="/francais-anglais/white_pixel.gif?number=548978192" width="1"/>
# </body></html>
# <!-- 2022-Jan-12 13:47:54 -->

# %%
souplettesBody = soup.find('div')
word = souplettesBody.findAll('div',{"class":"isForeignTerm"})

files = souplettesBody.findAll('a',{"class":"audio"})
word = [v.find("a").text.strip() for v in word][0]
print(word)
#files = [{}]
#print(word)
#print(mp3File[0])
files_split = files[0]["onclick"].replace("playSound","").replace(";","").replace("\"", "").split(",")
files_split = {files_split[1].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[1]+".mp3",files_split[3].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[3]+".mp3"}
# Out:
# <div id="ip_page_wrapper"><div id="ip_content_wrapper">
# <div class="tooltip" id="tooltip"> </div>
# <div id="selectionPopup">
# <ul class="selectionPopupActions">
# <li><a href="javascript:lingueeSearch()">Consulter Linguee</a></li>
# <li><a href="javascript:proposeTranslation()"> Proposer comme traduction pour "flower" </a></li>
# <li><a href="javascript:clipboardCopy()">Copier</a></li>
# </ul>
# <div class="selectionPopupFooter"></div>
# </div>
# <div class="il_FR il_FR" id="outer_div">
# <div id="mainlayout">
# <div id="banners_top">
# <div class="verticalAdText" id="banner_top">
# <div id="adngin-top_tablet_leaderboard-0"></div>
# </div>
# </div>
# <div id="snigel_ads_right" style="  top: 0;right: 0; position: absolute;text-align: center;">
# <div id="adngin-right_side_top-0" style="margin-bottom:10px;"></div>
# <div id="adngin-right_side_bottom_sticky-0"></div>
# </div>
# <div id="snigel_ads_left" style=" top: 0; left: 0; position: absolute; text-align: center;">
# <div id="adngin-left_side_top-0" style="margin-bottom:10px;"></div>
# <div id="adngin-left_side_bottom_sticky-0"></div>
# </div>
# <script type="text/javascript">
#                              var googletag = googletag || {};
#                              googletag.cmd = googletag.cmd || [];
#                          </script>
# <script type="text/javascript">
#                              var brosersAndVersions = navigator.userAgent.match(/(\w+)\/([0-9.]+)/g);
#                              var browsers = {};
#                              for (var i = 0; i < brosersAndVersions.length; ++i) {
#                                  var arr = brosersAndVersions[i].split("/");
#                                  browsers[arr[0]] = parseFloat(arr[1]);
#                              }
#
#                              var offset = function(el) {
#                                  var rect = el.getBoundingClientRect(), scrollLeft = window.pageXOffset || document.documentElement.scrollLeft, scrollTop = window.pageYOffset || document.documentElement.scrollTop;
#                                  return { top: rect.top + scrollTop, left: rect.left + scrollLeft };
#                              };
#
#                              var main = window.getComputedStyle(document.getElementById('mainlayout'));
#                              var outer_div = offset(document.getElementById('outer_div'));
#                              var mainPosition = offset(document.getElementById('mainlayout'));
#                              var scrollListener = function(main, element, side) {
#                                  var stickyPos = document.getElementById(element), offsetDiv = offset(stickyPos);
#                                  stickyPos.style.width = main;
#                                  window.addEventListener('scroll', function() {
#                                      var topDistance = window.scrollY;
#                                      if ($("#body").hasClass("parallax")) { topDistance = Math.abs(offset(document.getElementById('mainlayout')).top); }
#
#                                      if (offsetDiv.top <= 0) {
#                                        offsetDiv = offset(stickyPos);s
#                                        stickyPos.style.position = 'relative';
#                                        stickyPos.style.top = '0px';
#                                        stickyPos.style[side] = '0px';
#                                      } else if (topDistance >= offsetDiv.top) {
#                                        stickyPos.style.position = 'fixed';
#                                        if ($("#body").hasClass("parallax")) {
#                                          if (browsers["Safari"] >= 601) {
#                                            stickyPos.style.top = '0px';
#                                          } else {
#                                            stickyPos.style.top = topDistance + 'px';
#                                          }
#                                          stickyPos.style[side] = '0px';
#                                        } else {
#                                          stickyPos.style[side] = (outer_div.left + mainPosition.left) / 2 + 'px';
#                                        }
#                                      } else {
#                                          stickyPos.style.position = 'relative';
#                                          stickyPos.style.top = '0px';
#                                          stickyPos.style[side] = '0px';
#                                      }
#                                  }, true);
#                              };
#
#                              window.addEventListener('adnginLoaderReady', function () {
#                                adngin.queue.push(function () {
#                                  document.getElementById('adngin-right_side_top-0').style.width = main.getPropertyValue('padding-right');
#                                  document.getElementById('adngin-left_side_top-0').style.width = main.getPropertyValue('padding-left');
#                                  googletag.cmd.push(function () {
#                                    googletag.pubads().addEventListener('slotRenderEnded', function () {
#                                      document.getElementById('snigel_ads_right').style.top = ((window.innerWidth > 767 && window.innerWidth < 896) ? 108 : 0) + 'px';
#                                      scrollListener(main.getPropertyValue('padding-left'), 'adngin-left_side_bottom_sticky-0', 'left');
#                                      scrollListener(main.getPropertyValue('padding-right'), 'adngin-right_side_bottom_sticky-0', 'right');
#                                    });
#                                  });
#                                });
#                              });
#                          </script>
# <div class="mainpadding" id="maindiv">
# <link href="https://fonts.googleapis.com/css?family=Montserrat:300,400,500,600" rel="stylesheet"/>
# <nav class="lMainNavbar wide_in_main">
# <div class="lMainNavbar__left">
# <a class="lMainNavbar__deeplLogoLink" href="https://www.DeepL.com/translator">DeepL</a>
# <a class="lMainNavbar__translatorLink" href="https://www.DeepL.com/translator">Traducteur</a>
# <a class="lMainNavbar__lingueeLink is-active" href="/">Linguee</a>
# </div>
# <div class="lMainNavbar__right">
# <div class="lMainNavbar__buttonContainer">
# <div class="lMainNavbar__uiLangChooser"><button>FR</button></div>
# <div class="lMainNavbar__burgerButton"><button onclick="window.lMainNavbar.toggleBurgerMenu()">Open menu</button></div>
# </div>
# </div></nav>
# <template id="template_navPopup" style="display:none"> <div class="lNavPopup"> <div class="lNavPopup__overlay"></div> <div class="lNavPopup__window"> <button class="lNavPopup__closeButton"></button> <nav class="lNavPopup__navLinks"> <a class="lNavPopup__navLink lNavPopup__navLink--translator" href="https://www.DeepL.com/translator">Traducteur</a> <p class="lNavPopup__navLink-desc">Traduisez des textes avec la meilleure technologie de traduction automatique au monde, développée par les créateurs de Linguee.</p> <a class="lNavPopup__navLink lNavPopup__navLink--linguee" href="/">Linguee</a> <p class="lNavPopup__navLink-desc">Recherchez des traductions de mots et de phrases dans des dictionnaires bilingues, fiables et exhaustifs et parcourez des milliards de traductions en ligne.</p> <a class="lNavPopup__navLink" href="https://www.DeepL.com/blog.html">Blog</a> <a class="lNavPopup__navLink" href="https://www.DeepL.com/press.html">Informations presse</a> </nav> <div class="lNavPopup__appsSection"> <h2>Applications Linguee</h2> <a class="lNavPopup__appStoreLink appStoreLink" href="https://itunes.apple.com/de/app/id338225335?mt=8" target="_blank"><div class="AppStoreBadge appstore-logo"> </div></a> <a class="lNavPopup__appStoreLink playStoreLink" href="https://play.google.com/store/apps/details?id=com.linguee.linguee&amp;referrer=utm_source%3Dlinguee%26utm_medium%3Dunknown%26utm_campaign%3Dstart" target="_blank"><div class="PlayStoreBadge"> </div></a> </div> <script>
# 			window.$$initInstance && window.$$initInstance(function(node){
# 				function doClose(){
# 					node.parentNode.removeChild(node);
# 					node.doClose = undefined;
# 				}
# 				node.querySelector('.lNavPopup__closeButton').addEventListener('click', doClose);
# 				node.querySelector('.lNavPopup__overlay').addEventListener('click', doClose);
# 				node.doClose = doClose;
# 			});
# 			</script>
# </div>
# </div>
# </template>
# <script>
# 	window.lMainNavbar = {
# 	  toggleBurgerMenu: function(){
# 		  if (this._popupNode && this._popupNode.doClose){ this._popupNode.doClose(); this._popupNode = undefined; }
# 		  else this._popupNode = UI_Tools.createTemplateInstance('#template_navPopup', 'body');
# 		}
# 	};
# </script>
# <div class="wide_in_main l_header" id="header">
# <form accept-charset="utf-8" action="/francais-anglais/search" id="form1" method="get" name="bigform" onsubmit="return lingueeSubmitForm();">
# <div class="lQueryHeader">
# <a class="lQueryHeader__lingueeLogo" href="/">Linguee</a>
# <div class="lQueryHeader__langSelector">
# <select id="langPair" name="source">
# <option selected="selected" value="auto">[fr] français &lt;-&gt; [gb] anglais</option>
# <option value="francais">[fr] français ---&gt; [gb] anglais</option>
# <option class="dir_last" value="anglais">[gb] anglais ---&gt; [fr] français</option>
# <option value="/francais-allemand">[fr] français &lt;-&gt; [de] allemand</option>
# <option value="/francais-espagnol">[fr] français &lt;-&gt; [es] espagnol</option>
# <option value="/francais-portugais">[fr] français &lt;-&gt; [pt] portugais</option>
# <option value="/francais-italien">[fr] français &lt;-&gt; [it] italien</option>
# <option value="/francais-neerlandais">[fr] français &lt;-&gt; [nl] néerlandais</option>
# <option value="/francais-polonais">[fr] français &lt;-&gt; [pl] polonais</option>
# <option value="/francais-suedois">[fr] français &lt;-&gt; [se] suédois</option>
# <option value="/francais-danois">[fr] français &lt;-&gt; [dk] danois</option>
# <option value="/francais-finnois">[fr] français &lt;-&gt; [fi] finnois</option>
# <option value="/francais-grec">[fr] français &lt;-&gt; [gr] grec</option>
# <option value="/francais-tcheque">[fr] français &lt;-&gt; [cz] tchèque</option>
# <option value="/francais-roumain">[fr] français &lt;-&gt; [ro] roumain</option>
# <option value="/francais-hongrois">[fr] français &lt;-&gt; [hu] hongrois</option>
# <option value="/francais-slovaque">[fr] français &lt;-&gt; [sk] slovaque</option>
# <option value="/francais-bulgare">[fr] français &lt;-&gt; [bg] bulgare</option>
# <option value="/francais-slovene">[fr] français &lt;-&gt; [si] slovène</option>
# <option value="/francais-lituanien">[fr] français &lt;-&gt; [lt] lituanien</option>
# <option value="/francais-letton">[fr] français &lt;-&gt; [lv] letton</option>
# <option value="/francais-estonien">[fr] français &lt;-&gt; [ee] estonien</option>
# <option value="/francais-maltais">[fr] français &lt;-&gt; [mt] maltais</option>
# <option value="moreLanguages">Plus de langues</option>
# </select>
# </div>
# <div class="letterHelp lQueryHeader__letterHelp"><a href="javascript:addLetter('à');">à</a><a href="javascript:addLetter('â');">â</a><a href="javascript:addLetter('é');">é</a><a href="javascript:addLetter('è');">è</a><a href="javascript:addLetter('ê');">ê</a><a href="javascript:addLetter('ë');">ë</a><a href="javascript:addLetter('ï');">ï</a><a href="javascript:addLetter('î');">î</a><a href="javascript:addLetter('ô');">ô</a><a href="javascript:addLetter('ù');">ù</a><a href="javascript:addLetter('û');">û</a><a href="javascript:addLetter('ç');">ç</a><a href="javascript:addLetter('œ');">œ</a><a href="javascript:addLetter('æ');">æ</a></div>
# <script type="text/javascript">var letterHelp={gb:'àâéèêëïîôùûçœæ',de:'äöüßàâéèêëïîôùûçœæ',es:'áéíóúüñàâèêëïîôùûçœæ',pt:'áàãâéêíóõôúçèëïîùûœæ',fr:'àâéèêëïîôùûçœæ'}</script>
# <div class="lQueryHeader__input_container">
# <input autocapitalize="off" autocomplete="off" autocorrect="off" autofocus="" id="queryinput" maxlength="60" name="query" spellcheck="false" tabindex="1" type="text" value="flower"/>
# <button alt="Rechercher dans le dictionnaire français-anglais" type="submit"></button><div class="lQueryHeader__ac_container"></div></div>
# <div class="l_header__mobileLangButton" id="small_prefs"><span>FR</span><hr/><span>EN</span></div>
# </div><!--query_wrapper-->
# </form>
# </div> <!-- /header -->
# <script type="text/javascript">
# var LTexts = {button_audio: 'Écouter',button_search: 'Chercher',no_examples: 'Aucun exemple de sources externes.'}
# afterHeader()
# </script>
# <div id="lingueecontent">
# <div id="phraseeditAjaxDelay"></div>
# <div class="innercontent">
# <!-- DeepL Search Banner -->
# <div class="l_deepl_ad_container wide_in_main" style="display:none">
# <div class="l_deepl_ad__bg">
# </div>
# <div class="l_deepl_ad__content_container">
# <div class="l_deepl_ad_headercontainer">
# <div class="l_deepl_ad_header">Utilisez DeepL Traducteur pour traduire instantanément textes et documents</div>
# <div class="l_deepl_ad_header__mobile">Essayez DeepL Traducteur</div>
# </div>
# <div class="l_deepl_ad_bodycontainer">
# <div class="lmt__textarea_separator lmt__textarea_separator--left">
# <div class="lmt__textarea_separator__vertical_line"></div>
# <div class="lmt__textarea_separator__arrow"></div>
# <div class="lmt__textarea_separator__border_inner"></div>
# <div class="lmt__textarea_separator__border_outer"></div>
# <div class="lmt__textarea_separator__busy"></div>
# </div>
# <div class="l_deepl_ad__querytext lmt__textarea">flower</div>
# <div class="l_deepl_ad__copyListContainer">
# <ul>
# <li>Traduction en temps réel</li>
# <li>Meilleure qualité au monde</li>
# <li>Documents chargeables en « glisser-déposer »</li>
# </ul>
# <div class="l_deepl_ad__ctaButton" href="https://deepl.com">Essayer</div>
# </div>
# </div>
# </div>
# </div>
# <div id="dictionary">
# <h1 class="dict_headline_for_0 bothsides wide_in_main"><div class="openTriangle"> ▾</div>Dictionnaire anglais-français</h1>
# <div class="isForeignTerm" data-source-lang="EN"><div class="exact"><div class="lemma featured" wt="101"><div><h2 class="line lemma_desc" lid="EN:flower16102"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower.html" rel="nofollow">flower</a> <a class="audio" id="EN_US/60/608f0b988db4a96066af7dd8870de96c-100" onclick='playSound(this,"EN_US/60/608f0b988db4a96066af7dd8870de96c-100","anglais américain","EN_UK/60/608f0b988db4a96066af7dd8870de96c-100","anglais britannique");'></a> <span class="tag_wordtype">nom</span></span> <span class="tag_forms forms_plural"> (<span class="tag_formname">pluriel: </span><span class="tag_s"><a class="formLink" href="/anglais-francais/traduction/flowers.html" rel="nofollow">flowers</a></span>)</span><span class="dash">—</span></h2><div class="lemma_content"><div class="meaninggroup sortablemg" gid="0"><div class="translation_lines"><div class="translation sortablemg featured"><h3 class="translation_desc"><span bid="10000703605" class="tag_trans" lid="FR:fleur17529"><a class="dictLink featured" href="/francais-anglais/traduction/fleur.html" id="dictEntry10000703605">fleur</a> <span class="tag_type" title="nom, féminin">f</span> <a class="audio" id="FR/1e/1ea31d12c145f5b54332e6ae2bb04ab7-107" onclick='playSound(this,"FR/1e/1ea31d12c145f5b54332e6ae2bb04ab7-107","français");'></a><a class="expand_i"></a></span><!--tag_trans--> <span class="tag_forms forms_plural"> (<span class="tag_formname">pluriel: </span><span class="tag_t"><a class="formLink" href="/francais-anglais/traduction/fleurs.html" rel="nofollow">fleurs</a> <span class="tag_type">f</span></span>)</span></h3><!--translation_desc--><!-- editorial isFeatured 1 inType 0 allowFeatured 1 available: 2 -->
# <div class="example_lines"><div class="example line" sid="18369"><span class="tag_e"><span class="tag_s">She got flowers for her birthday.</span> <span class="dash">—</span> <span class="tag_t">Elle a reçu des fleurs pour son anniversaire.</span><span class="tag_e_end"></span></span></div><div class="example line" sid="31987"><span class="tag_e"><span class="tag_s">A layer of frost blanketed the flowers.</span> <span class="dash">—</span> <span class="tag_t">Une couche de givre recouvrait les fleurs.</span><span class="tag_e_end"></span></span></div></div></div>
# </div><!--translation_lines-->
# </div><!--meaninggroup-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma" wt="200"><div><h2 class="line lemma_desc" lid="EN:flower16102"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower.html" rel="nofollow">flower</a> <a class="audio" id="EN_US/60/608f0b988db4a96066af7dd8870de96c-200" onclick='playSound(this,"EN_US/60/608f0b988db4a96066af7dd8870de96c-200","anglais américain","EN_UK/60/608f0b988db4a96066af7dd8870de96c-200","anglais britannique");'></a> <span class="tag_wordtype">verbe</span></span> <span class="tag_forms forms_verb"> (<span class="tag_s"><a class="formLink" href="/anglais-francais/traduction/flowered.html">flowered</a></span>, <span class="tag_s"><a class="formLink" href="/anglais-francais/traduction/flowered.html">flowered</a></span>)</span><span class="dash">—</span></h2><div class="lemma_content"><div class="meaninggroup sortablemg" gid="0"><div class="translation_lines"><div class="translation sortablemg"><h3 class="translation_desc"><span bid="10000703620" class="tag_trans" lid="FR:fleurir49223"><a class="dictLink" href="/francais-anglais/traduction/fleurir.html" id="dictEntry10000703620">fleurir</a> <span class="tag_type" title="verbe">v</span> <a class="audio" id="FR/ce/ce9a6e6337661a9b5428e3d25b0f9585-200" onclick='playSound(this,"FR/ce/ce9a6e6337661a9b5428e3d25b0f9585-200","français");'></a><a class="expand_i"></a></span><!--tag_trans--></h3><!--translation_desc--><!-- editorial isFeatured 0 inType 0 allowFeatured 1 available: 0 -->
# </div>
# </div><!--translation_lines-->
# </div><!--meaninggroup-->
# </div><!--lemma_content--></div></div><!--lemma-->
# </div><!--exact--><div class="example_lines inexact"><h3>Exemples :</h3><div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+shop.html" lid="EN:flower#shop7798"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+shop.html">flower shop</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/f7/f764977216f5cca7e3ffa8e85947107e-101" onclick='playSound(this,"EN_UK/f7/f764977216f5cca7e3ffa8e85947107e-101","anglais britannique","EN_US/f7/f764977216f5cca7e3ffa8e85947107e-100","anglais américain");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10000787665" class="tag_trans" lid="FR:fleuriste3994"><a class="dictLink" href="/francais-anglais/traduction/fleuriste.html" id="dictEntry10000787665">fleuriste</a> <span class="tag_type" title="nom, masculin">m</span> <a class="audio" id="FR/91/91cc8d8405bff4764678cd38ab5e5a99-106" onclick='playSound(this,"FR/91/91cc8d8405bff4764678cd38ab5e5a99-106","français");'></a><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+arrangement.html" lid="EN:flower#arrangement63971"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+arrangement.html">flower arrangement</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/ee/eec367027038c7b7861ba42ef3fb2589-101" onclick='playSound(this,"EN_UK/ee/eec367027038c7b7861ba42ef3fb2589-101","anglais britannique","EN_US/ee/eec367027038c7b7861ba42ef3fb2589-100","anglais américain");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002599249" class="tag_trans" lid="FR:composition#florale58847"><a class="dictLink" href="/francais-anglais/traduction/composition+florale.html" id="dictEntry10002599249">composition florale</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# <span class="sep">·</span> </div>
# <div class="translation sortablemg"><div class="translation_desc"><span bid="10003062296" class="tag_trans" lid="FR:arrangement#floral6324"><a class="dictLink" href="/francais-anglais/traduction/arrangement+floral.html" id="dictEntry10003062296">arrangement floral</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="102"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+seeds.html" lid="EN:flower#seeds45156"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+seeds.html">flower seeds</a> <span class="tag_type" title="nom, pluriel">pl</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005151446" class="tag_trans" lid="FR:semences#de#fleurs55070"><a class="dictLink" href="/francais-anglais/traduction/semences+de+fleurs.html" id="dictEntry10005151446">semences de fleurs</a> <span class="tag_type" title="nom, pluriel, féminin">pl f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="expandable"><div class="versionShort"><a class="expandM" onclick="expandAnim(this)"></a></div><div class="versionLong"><div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+market.html" lid="EN:flower#market29543"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+market.html">flower market</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/58/58a3b21c3c157ab7f1b30b4b066604d9-100" onclick='playSound(this,"EN_UK/58/58a3b21c3c157ab7f1b30b4b066604d9-100","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002727957" class="tag_trans" lid="FR:march##aux#fleurs43527"><a class="dictLink" href="/francais-anglais/traduction/march%C3%A9+aux+fleurs.html" id="dictEntry10002727957">marché aux fleurs</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+industry.html" lid="EN:flower#industry64106"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+industry.html">flower industry</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004701624" class="tag_trans" lid="FR:industrie#floricole57176"><a class="dictLink" href="/francais-anglais/traduction/industrie+floricole.html" id="dictEntry10004701624">industrie floricole</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+pattern.html" lid="EN:flower#pattern528"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+pattern.html">flower pattern</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005473813" class="tag_trans" lid="FR:motif#floral19154"><a class="dictLink" href="/francais-anglais/traduction/motif+floral.html" id="dictEntry10005473813">motif floral</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# <span class="sep">·</span> </div>
# <div class="translation sortablemg"><div class="translation_desc"><span bid="10004624916" class="tag_trans" lid="FR:motif#fleuri41864"><a class="dictLink" href="/francais-anglais/traduction/motif+fleuri.html" id="dictEntry10004624916">motif fleuri</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# <span class="sep">·</span> </div>
# <div class="translation sortablemg"><div class="translation_desc"><span bid="10005447882" class="tag_trans" lid="FR:dessin#floral3170"><a class="dictLink" href="/francais-anglais/traduction/dessin+floral.html" id="dictEntry10005447882">dessin floral</a> <span class="tag_type" title="nom, masculin">m</span></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+basket.html" lid="EN:flower#basket3442"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+basket.html">flower basket</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/90/90ecaa638bf989ac3547a7638fa2b313-100" onclick='playSound(this,"EN_UK/90/90ecaa638bf989ac3547a7638fa2b313-100","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004674379" class="tag_trans" lid="FR:panier#fleuri20085"><a class="dictLink" href="/francais-anglais/traduction/panier+fleuri.html" id="dictEntry10004674379">panier fleuri</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+meadow.html" lid="EN:flower#meadow39011"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+meadow.html">flower meadow</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005159277" class="tag_trans" lid="FR:prairie#fleurie15841"><a class="dictLink" href="/francais-anglais/traduction/prairie+fleurie.html" id="dictEntry10005159277">prairie fleurie</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/cotton+flower.html" lid="EN:cotton#flower46051"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/cotton+flower.html">cotton flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005012201" class="tag_trans" lid="FR:fleur#de#coton48001"><a class="dictLink" href="/francais-anglais/traduction/fleur+de+coton.html" id="dictEntry10005012201">fleur de coton</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+nectar.html" lid="EN:flower#nectar26403"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+nectar.html">flower nectar</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004843734" class="tag_trans" lid="FR:nectar#de#fleur15353"><a class="dictLink" href="/francais-anglais/traduction/nectar+de+fleur.html" id="dictEntry10004843734">nectar de fleur</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/zucchini+flower.html" lid="EN:zucchini#flower13954"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/zucchini+flower.html">zucchini flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002904664" class="tag_trans" lid="FR:fleur#de#courgette24221"><a class="dictLink" href="/francais-anglais/traduction/fleur+de+courgette.html" id="dictEntry10002904664">fleur de courgette</a> <span class="tag_type" title="nom, féminin">f</span></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+delivery.html" lid="EN:flower#delivery8810"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+delivery.html">flower delivery</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004667069" class="tag_trans" lid="FR:livraison#de#fleurs794"><a class="dictLink" href="/francais-anglais/traduction/livraison+de+fleurs.html" id="dictEntry10004667069">livraison de fleurs</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+wreath.html" lid="EN:flower#wreath54670"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+wreath.html">flower wreath</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005135012" class="tag_trans" lid="FR:couronne#de#fleurs10061"><a class="dictLink" href="/francais-anglais/traduction/couronne+de+fleurs.html" id="dictEntry10005135012">couronne de fleurs</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/wilted+flower.html" lid="EN:wilted#flower47628"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/wilted+flower.html">wilted flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002904728" class="tag_trans" lid="FR:fleur#fan#e14242"><a class="dictLink" href="/francais-anglais/traduction/fleur+fan%C3%A9e.html" id="dictEntry10002904728">fleur fanée</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+carpet.html" lid="EN:flower#carpet38127"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+carpet.html">flower carpet</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005149062" class="tag_trans" lid="FR:tapis#de#fleurs52726"><a class="dictLink" href="/francais-anglais/traduction/tapis+de+fleurs.html" id="dictEntry10005149062">tapis de fleurs</a> <span class="tag_type" title="nom, masculin">m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+chain.html" lid="EN:flower#chain24554"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+chain.html">flower chain</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005153757" class="tag_trans" lid="FR:cha#ne#de#fleurs29510"><a class="dictLink" href="/francais-anglais/traduction/cha%C3%AEne+de+fleurs.html" id="dictEntry10005153757">chaîne de fleurs</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/little+flower.html" lid="EN:little#flower36821"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/little+flower.html">little flower</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/41/41bb0de8a4dd9c9a3221b094cb508450-100" onclick='playSound(this,"EN_UK/41/41bb0de8a4dd9c9a3221b094cb508450-100","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002915869" class="tag_trans" lid="FR:petite#fleur30535"><a class="dictLink" href="/francais-anglais/traduction/petite+fleur.html" id="dictEntry10002915869">petite fleur</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="102"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+arrangements.html" lid="EN:flower#arrangements14590"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+arrangements.html">flower arrangements</a> <span class="tag_type" title="nom, pluriel">pl</span> <a class="audio" id="EN_UK/a0/a0a6ad17cd73a85070ab8227e2467c98-102" onclick='playSound(this,"EN_UK/a0/a0a6ad17cd73a85070ab8227e2467c98-102","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005021218" class="tag_trans" lid="FR:compositions#florales41858"><a class="dictLink" href="/francais-anglais/traduction/compositions+florales.html" id="dictEntry10005021218">compositions florales</a> <span class="tag_type" title="nom, pluriel, féminin">pl f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/artificial+flower.html" lid="EN:artificial#flower48424"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/artificial+flower.html">artificial flower</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/f5/f58a09ef1cd6e24fab75c53528bab68d-100" onclick='playSound(this,"EN_UK/f5/f58a09ef1cd6e24fab75c53528bab68d-100","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004890194" class="tag_trans" lid="FR:fleur#artificielle63600"><a class="dictLink" href="/francais-anglais/traduction/fleur+artificielle.html" id="dictEntry10004890194">fleur artificielle</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/small+flower.html" lid="EN:small#flower5138"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/small+flower.html">small flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10003229420" class="tag_trans" lid="FR:petite#fleur30535"><a class="dictLink" href="/francais-anglais/traduction/petite+fleur.html" id="dictEntry10003229420">petite fleur</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/fresh-cut+flower.html" lid="EN:fresh#cut#flower64493"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/fresh-cut+flower.html">fresh-cut flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004757006" class="tag_trans" lid="FR:fleur#coup#e63033"><a class="dictLink" href="/francais-anglais/traduction/fleur+coup%C3%A9e.html" id="dictEntry10004757006">fleur coupée</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/single+flower.html" lid="EN:single#flower49375"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/single+flower.html">single flower</a> <span class="tag_type" title="nom">n</span> <a class="audio" id="EN_UK/18/1875d86b35c25aa44b881724c03be513-100" onclick='playSound(this,"EN_UK/18/1875d86b35c25aa44b881724c03be513-100","anglais britannique");'></a></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10004890234" class="tag_trans" lid="FR:fleur#unique13582"><a class="dictLink" href="/francais-anglais/traduction/fleur+unique.html" id="dictEntry10004890234">fleur unique</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# <span class="sep">·</span> </div>
# <div class="translation sortablemg"><div class="translation_desc"><span bid="10004887279" class="tag_trans" lid="FR:seule#fleur37301"><a class="dictLink" href="/francais-anglais/traduction/seule+fleur.html" id="dictEntry10004887279">seule fleur</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="101"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/fine+flower.html" lid="EN:fine#flower10138"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/fine+flower.html">fine flower</a> <span class="tag_type" title="nom">n</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10002746593" class="tag_trans" lid="FR:fine#fleur48334"><a class="dictLink" href="/francais-anglais/traduction/fine+fleur.html" id="dictEntry10002746593">fine fleur</a> <span class="tag_type" title="nom, féminin">f</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# <div class="lemma singleline" wt="102"><div><h2 class="line lemma_desc" href="/anglais-francais/traduction/flower+buds.html" lid="EN:flower#buds23025"><span class="tag_lemma"><a class="dictLink" href="/anglais-francais/traduction/flower+buds.html">flower buds</a> <span class="tag_type" title="nom, pluriel">pl</span></span><span class="dash">—</span></h2><div class="lemma_content"><div class="translation_lines"><div class="translation_group"><div class="line group_line translation_group_line"><div class="translation sortablemg translation_first"><div class="translation_desc"><span bid="10005035775" class="tag_trans" lid="FR:boutons#de#fleurs35854"><a class="dictLink" href="/francais-anglais/traduction/boutons+de+fleurs.html" id="dictEntry10005035775">boutons de fleurs</a> <span class="tag_type" title="nom, pluriel, masculin">pl m</span><a class="expand_i"></a></span><!--tag_trans--></div><!--translation_desc--><!-- editorial isFeatured 0 inType 1 allowFeatured 1 available: 0 -->
# </div>
# </div></div>
# </div><!--translation_lines-->
# </div><!--lemma_content--></div></div><!--lemma-->
# ...
# <div class="shortened_end2">vous portez sur votre chemise.</div>
# <div class="source_url_spacer">legion.ca</div>
# <div class="source_url"><a href="http://www.legion.ca/_PDF/Teachers/T_GUIDE_F.pdf" rel="noopener noreferrer" target="_blank">legion.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_5325080629_0">
# <td class="sentence left"><div class="wrap">
# It is a deli<b class="b1">ca</b><b class="b2">t</b><b class="b3">e</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">a</b><b class="b2">n</b><b class="b1">d </b>we all want it <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">to be a success.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20000906+ITEMS+DOC+XML+V0//EN&amp;amp;language=EN" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Il s'agit <b class="b1">d'</b><b class="b2">une </b><b class="b3">jeun</b><b class="b4">e </b><b class="b5">pousse</b><b class="b4"> e</b><b class="b3">t no</b><b class="b2">us v</b><b class="b1">ou</b>lons tous <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">qu'elle prospère.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20000906+ITEMS+DOC+XML+V0//FR&amp;amp;language=FR" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8767649588_0">
# <td class="sentence left"><div class="wrap">
# If the crop has been tryin<b class="b1">g </b><b class="b2">t</b><b class="b3">o</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">f</b><b class="b2">o</b><b class="b1">r </b>four or more days but cannot because of the lygus pressure, the insecticide should reduce the lygus to a level that will a<b class="b1">ll</b><b class="b2">o</b><b class="b3">w</b><b class="b4"> </b><b class="b5">flowering</b>. <div class="source_url_spacer">sca-fcc.ca</div>
# <div class="source_url"><a href="http://www.sca-fcc.ca/newsletters/en/express/articles/20100709_e.asp" rel="noopener noreferrer" target="_blank">sca-fcc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Si les plants s'ef<b class="b1">fo</b><b class="b2">rcent</b><b class="b3"> de</b><b class="b4"> fleurir </b><b class="b3">dep</b><b class="b2">uis q</b><b class="b1">ua</b>tre jours ou plus mais n'y parviennent pas en raison de l'action des punaises, l'insecticide devrait réduire la population d'insectes à un nombr<b class="b1">e </b><b class="b2">propi</b><b class="b3">ce </b><b class="b4">à l</b><b class="b5">a floraison</b>. <div class="source_url_spacer">sca-fcc.ca</div>
# <div class="source_url"><a href="http://www.sca-fcc.ca/newsletters/fr/express/articles/20100709_f.asp" rel="noopener noreferrer" target="_blank">sca-fcc.ca</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_1626665108_0">
# <td class="sentence left"><div class="wrap">
# Some honey drops conta<b class="b1">in</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">flower</b>. <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/en-EN/help/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# <div class="shortened_begin2">Certaines gouttes de</div>
# <span class="placeholder_begin2">[...] </span>
#  miel cont<b class="b1">ie</b><b class="b2">nnent</b><b class="b3"> un</b><b class="b4">e fleur</b>. <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/fr-FR/aide/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_3777300801_0">
# <td class="sentence left"><div class="wrap">
# I only recognise the li<b class="b1">tt</b><b class="b2">l</b><b class="b3">e</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">w</b><b class="b2">i</b><b class="b1">th</b> the circle of <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">stars around it from a brand of toilet paper.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20090402+ITEMS+DOC+XML+V0//EN&amp;amp;language=EN" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Je ne conn<b class="b1">ai</b><b class="b2">s la </b><b class="b3">pet</b><b class="b4">ite</b><b class="b5"> fleur </b><b class="b4">ent</b><b class="b3">our</b><b class="b2">ée d'</b><b class="b1">un</b> cercle <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">d'étoiles que grâce à une marque de papier hygiénique.</div>
# <div class="source_url_spacer">europarl.europa.eu</div>
# <div class="source_url"><a href="http://www.europarl.europa.eu/sides/getDoc.do?pubRef=-//EP//TEXT+CRE+20090402+ITEMS+DOC+XML+V0//FR&amp;amp;language=FR" rel="noopener noreferrer" target="_blank">europarl.europa.eu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_465270090_0">
# <td class="sentence left"><div class="wrap">
# <div class="shortened_begin2">How many times did his disciples or the people see Jesus</div>
# <span class="placeholder_begin2">[...] </span>
#  caressing a bird <b class="b1">or</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">flower</b><b class="b4">,</b><b class="b3"> </b><b class="b2">a</b><b class="b1">nd</b> blessing them all. <div class="source_url_spacer">das-dritte-testament.com</div>
# <div class="source_url"><a href="http://das-dritte-testament.com/E/CapII.htm" rel="noopener noreferrer" target="_blank">das-dritte-testament.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# <div class="shortened_begin2">A maintes reprises les disciples et les gens virent Jésus</div>
# <span class="placeholder_begin2">[...] </span>
#  caresser un o<b class="b1">is</b><b class="b2">eau o</b><b class="b3">u u</b><b class="b4">ne</b><b class="b5"> fleur </b><b class="b4">et</b><b class="b3"> bé</b><b class="b2">nissa</b><b class="b1">nt</b> tout. <div class="source_url_spacer">das-dritte-testament.com</div>
# <div class="source_url"><a href="http://das-dritte-testament.com/F/CapII.htm" rel="noopener noreferrer" target="_blank">das-dritte-testament.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_4451070132_0">
# <td class="sentence left"><div class="wrap">
# <div class="shortened_begin2">On the left</div>
# <span class="placeholder_begin2">[...] </span>
#  side, you'll fi<b class="b1">nd</b><b class="b2"> </b><b class="b3">a</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">w</b><b class="b2">h</b><b class="b1">er</b>e the bee flies <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">around when you score points.</div>
# <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/en-EN/help/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# Sur la gauche s<b class="b1">e </b><b class="b2">trouv</b><b class="b3">e u</b><b class="b4">ne</b><b class="b5"> fleur </b><b class="b4">au</b><b class="b3">tou</b><b class="b2">r de </b><b class="b1">la</b>quelle <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">l'abeille vole lorsque vous marquez des points.</div>
# <div class="source_url_spacer">zigiz.com</div>
# <div class="source_url"><a href="http://www.zigiz.com/fr-FR/aide/help_parent_game_rules/help_bumbletumble.html" rel="noopener noreferrer" target="_blank">zigiz.com</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
# <tr class="" id="row_0_8461737982_0">
# <td class="sentence left"><div class="wrap">
# The t<b class="b1">ul</b><b class="b2">i</b><b class="b3">p</b><b class="b4"> </b><b class="b5">flower</b><b class="b4"> </b><b class="b3">r</b><b class="b2">e</b><b class="b1">se</b>mbles a turban, and <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">that is why the Turkish name for tulip is "Tuliband".</div>
# <div class="source_url_spacer">euro-cordiale.lu</div>
# <div class="source_url"><a href="http://www.euro-cordiale.lu/compro/files/EN/D/D3_33.pdf" rel="noopener noreferrer" target="_blank">euro-cordiale.lu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# <td class="sentence right2"><div class="wrap">
# L<b class="b3">a </b><b class="b4">fleur</b><b class="b3"> d'</b><b class="b2">une t</b><b class="b1">uli</b><b class="b2">pe rappelle un</b><b class="b1"> t</b>urban, <span class="placeholder_end2"> [...]</span>
# <div class="shortened_end2">c'est pourquoi le nom turc de la tulipe est « Tuliband ».</div>
# <div class="source_url_spacer">euro-cordiale.lu</div>
# <div class="source_url"><a href="http://www.euro-cordiale.lu/compro/files/FR/D/D3_33.pdf" rel="noopener noreferrer" target="_blank">euro-cordiale.lu</a></div><div class="behindLinkDiv"></div>
# </div></td>
# </tr>
#
#  <!-- /result_table -->
# </div> <!-- /result_div -->
# </div>
# <!-- /result_container -->
# </div><!--innercontent-->
# </div><!--lingueecontent-->
# <div class="footer" id="footer">
# <div id="attribution">
# </div>
# <div id="currently_searched">Requêtes en cours :
# <a href="/francais-anglais/traduction/art+de+vivre.html">art de vivre</a>, <a href="/anglais-francais/traduction/labour+intensive.html">labour intensive</a>, <a href="/francais-anglais/traduction/je+vous+souhaite+une+tr%C3%A8s+bonne+ann%C3%A9e.html">je vous souhaite une très bonne année</a>, <a href="/anglais-francais/traduction/business+purpose.html">business purpose</a>, <a href="/francais-anglais/traduction/gare.html">gare</a>, <a href="/anglais-francais/traduction/luxembourg.html">luxembourg</a>, <a href="/francais-anglais/traduction/de+fa%C3%A7on+permanente.html">de façon permanente</a>, <a href="/anglais-francais/traduction/sensing.html">sensing</a>, <a href="/francais-anglais/traduction/aurait+pu.html">aurait pu</a>, <a href="/anglais-francais/traduction/hectic.html">hectic</a>, <a href="/francais-anglais/traduction/pendant+cette+p%C3%A9riode.html">pendant cette période</a>, <a href="/anglais-francais/traduction/pulley.html">pulley</a>, <a href="/francais-anglais/traduction/collation.html">collation</a>, <a href="/anglais-francais/traduction/point+of+care.html">point of care</a>, <a href="/francais-anglais/traduction/il+va+bien.html">il va bien</a></div>
# <div id="important_terms">Requête la plus fréquente dans le dictionnaire français :
#  <a href="/french-english/topfrench/1-200.html">1-200</a>, <a href="/french-english/topfrench/201-1000.html">-1k</a>, <a href="/french-english/topfrench/1001-2000.html">-2k</a>, <a href="/french-english/topfrench/2001-3000.html">-3k</a>, <a href="/french-english/topfrench/3001-4000.html">-4k</a>, <a href="/french-english/topfrench/4001-5000.html">-5k</a>, <a href="/french-english/topfrench/5001-7000.html">-7k</a>, <a href="/french-english/topfrench/7001-10000.html">-10k</a>
# , <a href="/french-english/topfrench/10001-20000.html">-20k</a>, <a href="/french-english/topfrench/20001-40000.html">-40k</a>, <a href="/french-english/topfrench/40001-100000.html">-100k</a>, <a href="/french-english/topfrench/100001-200000.html">-200k</a>, <a href="/french-english/topfrench/200001-500000.html">-500k</a>, <a href="/french-english/topfrench/500001-2200000.html">-1000k</a><br/>
# Requête la plus fréquente dans le dictionnaire anglais :
#  <a href="/english-french/topenglish/1-200.html">1-200</a>, <a href="/english-french/topenglish/201-1000.html">-1k</a>, <a href="/english-french/topenglish/1001-2000.html">-2k</a>, <a href="/english-french/topenglish/2001-3000.html">-3k</a>, <a href="/english-french/topenglish/3001-4000.html">-4k</a>, <a href="/english-french/topenglish/4001-5000.html">-5k</a>, <a href="/english-french/topenglish/5001-7000.html">-7k</a>, <a href="/english-french/topenglish/7001-10000.html">-10k</a>
# , <a href="/english-french/topenglish/10001-20000.html">-20k</a>, <a href="/english-french/topenglish/20001-40000.html">-40k</a>, <a href="/english-french/topenglish/40001-100000.html">-100k</a>, <a href="/english-french/topenglish/100001-200000.html">-200k</a>, <a href="/english-french/topenglish/200001-500000.html">-500k</a>, <a href="/english-french/topenglish/500001-2200000.html">-1000k</a><br/>
# </div>
# <div class="footer__inner"><nav class="footer__nav" id="footerNav"><a href="https://www.linguee.com/english-french/translation/flower.html" onclick="differentDomain(this)"><span>Linguee</span> in English</a>
# <a href="/francais-anglais/page/login.php" rel="nofollow">Connexion</a>
# <a href="/francais-anglais/page/imprint.php" rel="nofollow">Mentions légales</a>
# <a href="/francais-anglais/page/termsAndConditions.php" rel="nofollow">CGU</a>
# <a href="/francais-anglais/page/privacy.php" rel="nofollow">Déclaration de confidentialité</a></nav><div class="footer__socials"><a class="footer__social footer__social--twitter" href="https://twitter.com/DeepLcom" rel="noopener" target="_blank" title="Twitter"></a><a class="footer__social footer__social--facebook" href="https://www.facebook.com/DeepLcom/" rel="noopener" target="_blank"></a><a class="footer__social footer__social--linkedin" href="https://www.linkedin.com/company/linkedin-com-company-deepl/" rel="noopener" target="_blank"></a></div></div></div> <!-- /footer -->
# </div><!--maindiv--></div><!--mainlayout-->
# <div class="dialog" id="voteDownReasonDiv">
# <a class="button_close" onclick="forgetVoteDown()"></a>
# <b>Veuillez choisir une raison pour justifier votre évaluation de la traduction :</b>
# <ul><li id="vdBadExample"><a onclick="vdBadExample()">Cet exemple ne correspond à la traduction ci-dessus.</a></li>
# <li id="vdWrongBoldWords"><a onclick="vdWrongBoldWords()">Les mots surlignés ne correspondent pas.</a></li>
# <li id="vdDoesNotFitForQuery"><a onclick="vdDoesNotFitForQuery()">Ce résultat ne correspond pas à ma recherche.</a></li>
# <li id="vdShouldNotBeCombined"><a onclick="vdShouldNotBeCombined()">Cet exemple ne correspond pas à l'entrée en orange.</a></li>
# <li id="vdBadTranslation"><a onclick="vdBadTranslation()">La traduction est fausse ou de mauvaise qualité.</a></li>
# </ul>
# </div>
# <div class="dialog" id="voteThankYouDiv">
# <a class="button_close" onclick='jQuery("#voteThankYouDiv").fadeOut("fast")'></a>
# Merci d'avoir donné votre avis sur cette traduction !<br/> Vous contribuez ainsi à l'amélioration de notre service.
# </div>
# <link href="https://d1wigddrwdtsce.cloudfront.net/5_f079dcc8/css3/style4-late.min.css.g" rel="stylesheet" type="text/css"/><script src="https://d1wigddrwdtsce.cloudfront.net/5_f079dcc8/javascript/linguee4-all-late.min.js.g" type="text/javascript"></script>
# <script type="text/javascript">callDocumentReady();</script>
# <script type="text/javascript">
#   abpFormat='rectangle';
#   //if (document.documentElement.clientWidth*document.documentElement.clientHeight*0.15>=600*300) {
#   //  abpFormat='halfpage';
#   //}
# </script>
# <script type="text/javascript">
# if (isIE || isEdge || isIENewer) { window.performance=null; }
# </script>
# <script type="text/javascript">
# </script>
# </div></div>

# %%
soupletteAside = souplettesBody.find('a')
soupletteAside
# Out:
# <a href="javascript:lingueeSearch()">Consulter Linguee</a>

# %%
word = souplettesBody.findAll('div',{"class":"isForeignTerm"})

files = souplettesBody.findAll('a',{"class":"audio"})
word = [v.find("a").text.strip() for v in word][0]
print(word)
#files = [{}]
#print(word)
#print(mp3File[0])
files_split = files[0]["onclick"].replace("playSound","").replace(";","").replace("\"", "").split(",")
files_split = {files_split[1].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[1]+".mp3",files_split[3].split("/")[0]:"https://www.linguee.fr/mp3/"+files_split[3]+".mp3"}
files_split
# Out:
# flower
# {'EN_UK': 'https://www.linguee.fr/mp3/EN_UK/60/608f0b988db4a96066af7dd8870de96c-100.mp3',
#  'EN_US': 'https://www.linguee.fr/mp3/EN_US/60/608f0b988db4a96066af7dd8870de96c-100.mp3'}

# %%
for v in finded:
    vH4 = v.find('h4').text.strip()
    if "Identifiant" in vH4:
        print(vH4)
        
        soupletteV = v.find('div',{"class":"value"})
        print(soupletteV)
        print(soupletteV.text)
        
        vJPG = soupletteV.text.strip()
        print(vJPG)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-ccc95ad08eca> in <module>()
#       1 for v in finded:
# ----> 2     vH4 = v.find('h4').text.strip()
#       3     if "Identifiant" in vH4:
#       4         print(vH4)
#       5
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
for v in finded:
    vH4 = v.find('h4').text.strip()
    if "Identifiant" in vH4:
     
        soupletteV = v.find('div',{"class":"value"})
        vJPG = soupletteV.text.strip()
        print(vJPG)
# Out:
# FRAD86_16J3_37_088_8927.jpg

# %% [markdown]
# ## list url

# %%
urlTargetCarnet = "https://transcrire.huma-num.fr/scripto/1/20/media"
responseCarnet = requests.get(urlTargetCarnet)   
    
soupCarnet = BeautifulSoup(responseCarnet.text,'html.parser')
souplettesContent = soup.find('main',{"class":"wrapper__content"})
souplettesContent

# %%
finded = souplettesContent.findAll("li",{"class":"thumbnail-links__item"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-702eb3921ff7> in <module>()
# ----> 1 finded = souplettesContent.findAll("li",{"class":"thumbnail-links__item"})
#       2
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %%
for v in finded:
    a = v.find('a')
    print(a['href'])
# Out:
# /scripto/1/20/466
# /scripto/1/20/467
# /scripto/1/20/468
# /scripto/1/20/469
# /scripto/1/20/470
# /scripto/1/20/471
# /scripto/1/20/472
# /scripto/1/20/473
# /scripto/1/20/474
# /scripto/1/20/475
# /scripto/1/20/476
# /scripto/1/20/477

# %%
targetCarnet = "https://transcrire.huma-num.fr/scripto/1/20/media?sort_by=position&sort_order=asc&page=33"

responseC = requests.get(targetCarnet)

responseC.status_code
# Out:
# 200
